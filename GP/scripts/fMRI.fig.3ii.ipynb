# %%
from os.path import join, dirname, expanduser
from glob import glob

import numpy as np
import pandas as pd
import seaborn as sns

import statsmodels.formula.api as smf

import matplotlib.pyplot as plt
from matplotlib import cm, colors, patches, lines
from matplotlib.patches import Rectangle

from scipy import optimize, stats

# from nilearn import image, plotting, masking
# from nilearn.maskers import NiftiLabelsMasker

# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# from sklearn.decomposition import PCA
# from sklearn.metrics import confusion_matrix, classification_report
# from sklearn.preprocessing import StandardScaler

# from tqdm import tqdm

# import pingouin as pg

# %%
def convert_pvalue_to_asterisks(pvalue):
    if pvalue <= 0.0001:
        return "****"
    elif pvalue <= 0.001:
        return "***"
    elif pvalue <= 0.01:
        return "**"
    elif pvalue <= 0.05:
        return "*"
    return "ns"

# %%
dir_root = join('/mnt/ext5/GP/fmri_data')
dir_stat = join(dir_root,'stats/AM/GLM.reward_per_trial/5.0s_shifted')
dir_mask = join(dir_root,'masks')
# dir_home = expanduser('~')
dir_home = 'D:/'

# %%
img_bg = join('/usr/local/afni/abin/MNI152_2009_template.nii.gz')

# %%
list_dlPFC_cTBS = [
    '09', '10', '18', '21', '22'
    , '24', '27', '34', '35', '36'
    , '38', '42', '57', '59', '62'
    , '66', '67'
]
list_M1_cTBS = [
    '08', '11', '17', '19', '20'
    , '26', '32', '33', '37', '39'
    , '40', '41', '56', '58', '61'
    , '63', '65'
]
## GP50은 GP26과 동일인물
list_dlPFC_20Hz = [
    '43', '44', '45', '46', '47'
    , '48', '49', '51', '53', '54'
    , '55', '71', '72', '73', '74'
    , '75'
#     , '50'
]
list_subj = sorted(list_dlPFC_cTBS+list_M1_cTBS+list_dlPFC_20Hz)

# %%
list_run = ['r%02d'%(rr+1) for rr in range(3)]
list_group = ['no_stim','DLPFC_cTBS','M1_cTBS','DLPFC_20Hz']
list_roi = ['LaCA','LpCA','RaCA','RpCA','LaPU','LpPU','RaPU','RpPU']

# %% [markdown]
# ---

# %% [markdown]
# ## Import the result

# %%
# df = pd.read_excel('./KJH/LME/data/Rew#1_Coef_GPn50_KJH.xlsx')
# df['stim'] = ['yes' if subj[1]!='A' else 'no' for subj in df.subj]
# df.time += 1
# df

# %%
df = pd.read_excel(join(dir_home,'Github/labs/GP/results/performance_related_activity.8_striatum.xlsx'))
df = df.drop(columns=['roi_'])
df['time'] = [1 if run=='r01' else (2 if run=='r02' else (3 if run=='r03' else 0)) for run in df.run]
df['striatum'] = ['caudate' if roi[2:]=='CA' else ('putamen' if roi[2:]=='PU' else 'invalid') for roi in df.roi]
df['LR'] = [roi[0] for roi in df.roi]
df['AP'] = [roi[1] for roi in df.roi]
df
# Out:
#       subj       group  run   roi      beta  nvoxels   beta_sum  time  \
# 0     GA01     no_stim  r01  RaPU  0.518611      135  70.012471     1
# 1     GA01     no_stim  r01  LaPU  0.599993      133  79.799052     1
# 2     GA01     no_stim  r01  LpPU  0.151185      132  19.956442     1
# 3     GA01     no_stim  r01  RpPU  0.272298      105  28.591297     1
# 4     GA01     no_stim  r01  LaCA  0.538827       71  38.256683     1
# ...    ...         ...  ...   ...       ...      ...        ...   ...
# 1915  GP75  DLPFC_20Hz  r03  RpPU  0.614432      105  64.515351     3
# 1916  GP75  DLPFC_20Hz  r03  LaCA  0.917109       71  65.114770     3
# 1917  GP75  DLPFC_20Hz  r03  LpCA  0.538714      103  55.487529     3
# 1918  GP75  DLPFC_20Hz  r03  RaCA  1.086447       66  71.705534     3
# 1919  GP75  DLPFC_20Hz  r03  RpCA  0.616211      109  67.166992     3
#
#      striatum LR AP
# 0     putamen  R  a
# 1     putamen  L  a
# 2     putamen  L  p
# 3     putamen  R  p
# 4     caudate  L  a
# ...       ... .. ..
# 1915  putamen  R  p
# 1916  caudate  L  a
# 1917  caudate  L  p
# 1918  caudate  R  a
# 1919  caudate  R  p
#
# [1920 rows x 11 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Make LME datafram

# %% [markdown]
# 1. beta ~ time*C(group, Treatment('%s'))

# %%
group_ref = 'no_stim'

# %%
df_LME = pd.DataFrame()
for roi in list_roi:    
    for ii, group_ref in enumerate(list_group):
        df_tmp = df[df['roi']==roi]
        model = smf.mixedlm(
            "beta ~ time*C(group, Treatment('%s'))"%group_ref,
            df_tmp,
            groups=df_tmp['subj']
        )
        result = model.fit()
        # print(result.summary())
        for jj, group in enumerate(list_group[ii+1:]):
            new_row = pd.Series(
                {
                    'roi':roi, 'group_ref':group_ref, 'group':group,
                    # 'Intercept':result.params.Intercept + result.params["C(group, Treatment('%s'))[T.%s]"%(group_ref,group)],
                    'Intercept':result.params["C(group, Treatment('%s'))[T.%s]"%(group_ref,group)],
                    # 'Slope':result.params.time + result.params["time:C(group, Treatment('%s'))[T.%s]"%(group_ref,group)],
                    'Slope':result.params["time:C(group, Treatment('%s'))[T.%s]"%(group_ref,group)],
                    'SE_Intercept':result.bse_fe["C(group, Treatment('%s'))[T.%s]"%(group_ref,group)],
                    'SE_Slope':result.bse_fe["time:C(group, Treatment('%s'))[T.%s]"%(group_ref,group)],
                    'pval_Intercept':result.pvalues["C(group, Treatment('%s'))[T.%s]"%(group_ref,group)],
                    'pval_Slope':result.pvalues["time:C(group, Treatment('%s'))[T.%s]"%(group_ref,group)]
                }
            )
            df_LME = pd.concat(
                [df_LME, new_row.to_frame().T]
                , axis='index'
                , ignore_index=True
            )
df_LME
# Out:
#      roi   group_ref       group Intercept     Slope SE_Intercept  SE_Slope  \
# 0   LaCA     no_stim  DLPFC_cTBS  0.296152 -0.177475     0.128811  0.047896
# 1   LaCA     no_stim     M1_cTBS  0.033877  0.012246     0.128811  0.047896
# 2   LaCA     no_stim  DLPFC_20Hz -0.072512  0.039792     0.131355  0.048842
# 3   LaCA  DLPFC_cTBS     M1_cTBS -0.262275  0.189722     0.145539  0.054116
# 4   LaCA  DLPFC_cTBS  DLPFC_20Hz -0.368664  0.217267     0.147795  0.054955
# 5   LaCA     M1_cTBS  DLPFC_20Hz -0.106389  0.027545     0.147795  0.054955
# 6   LpCA     no_stim  DLPFC_cTBS  0.126062 -0.089273     0.138693   0.05158
# 7   LpCA     no_stim     M1_cTBS -0.078917  0.061624     0.138693   0.05158
# 8   LpCA     no_stim  DLPFC_20Hz -0.174191  0.108495     0.141432  0.052599
# 9   LpCA  DLPFC_cTBS     M1_cTBS -0.204979  0.150897     0.156704  0.058279
# 10  LpCA  DLPFC_cTBS  DLPFC_20Hz -0.300253  0.197767     0.159134  0.059182
# 11  LpCA     M1_cTBS  DLPFC_20Hz -0.095274  0.046871     0.159134  0.059182
# 12  RaCA     no_stim  DLPFC_cTBS   0.15308 -0.135807     0.131173  0.048044
# 13  RaCA     no_stim     M1_cTBS -0.017416  0.025933     0.131173  0.048044
# 14  RaCA     no_stim  DLPFC_20Hz  -0.14306  0.062223     0.133764  0.048992
# 15  RaCA  DLPFC_cTBS     M1_cTBS -0.170496  0.161739     0.148208  0.054283
# 16  RaCA  DLPFC_cTBS  DLPFC_20Hz -0.296139  0.198029     0.150506  0.055124
# 17  RaCA     M1_cTBS  DLPFC_20Hz -0.125644   0.03629     0.150506  0.055124
# 18  RpCA     no_stim  DLPFC_cTBS  0.204877 -0.137674     0.130728  0.048892
# 19  RpCA     no_stim     M1_cTBS -0.107592  0.061169     0.130728  0.048892
# 20  RpCA     no_stim  DLPFC_20Hz  -0.14382  0.094359      0.13331  0.049857
# 21  RpCA  DLPFC_cTBS     M1_cTBS -0.312469  0.198843     0.147705  0.055241
# 22  RpCA  DLPFC_cTBS  DLPFC_20Hz -0.348697  0.232033     0.149995  0.056097
# 23  RpCA     M1_cTBS  DLPFC_20Hz -0.036228   0.03319     0.149995  0.056097
# 24  LaPU     no_stim  DLPFC_cTBS  0.058694 -0.083082     0.126619  0.045907
# 25  LaPU     no_stim     M1_cTBS -0.047494  0.052312     0.126619  0.045907
# 26  LaPU     no_stim  DLPFC_20Hz -0.203857   0.08011      0.12912  0.046814
# 27  LaPU  DLPFC_cTBS     M1_cTBS -0.106188  0.135395     0.143062  0.051869
# 28  LaPU  DLPFC_cTBS  DLPFC_20Hz -0.262551  0.163193      0.14528  0.052673
# 29  LaPU     M1_cTBS  DLPFC_20Hz -0.156363  0.027798      0.14528  0.052673
# 30  LpPU     no_stim  DLPFC_cTBS  -0.00336 -0.003814     0.100237  0.038906
# 31  LpPU     no_stim     M1_cTBS -0.111734  0.069435     0.100237  0.038906
# 32  LpPU     no_stim  DLPFC_20Hz -0.105974  0.065955     0.102217  0.039675
# 33  LpPU  DLPFC_cTBS     M1_cTBS -0.108374  0.073249     0.113255  0.043959
# 34  LpPU  DLPFC_cTBS  DLPFC_20Hz -0.102614  0.069769     0.115011   0.04464
# 35  LpPU     M1_cTBS  DLPFC_20Hz   0.00576  -0.00348     0.115011   0.04464
# 36  RaPU     no_stim  DLPFC_cTBS  0.125206 -0.106202     0.113841  0.041011
# 37  RaPU     no_stim     M1_cTBS -0.020592   0.00736     0.113841  0.041011
# 38  RaPU     no_stim  DLPFC_20Hz -0.183366  0.058693      0.11609  0.041821
# 39  RaPU  DLPFC_cTBS     M1_cTBS -0.145798  0.113562     0.128625  0.046337
# 40  RaPU  DLPFC_cTBS  DLPFC_20Hz -0.308572  0.164895     0.130619  0.047056
# 41  RaPU     M1_cTBS  DLPFC_20Hz -0.162774  0.051333     0.130619  0.047056
# 42  RpPU     no_stim  DLPFC_cTBS -0.030284  0.001119     0.093535  0.034897
# 43  RpPU     no_stim     M1_cTBS -0.089746  0.048411     0.093535  0.034897
# 44  RpPU     no_stim  DLPFC_20Hz -0.132277  0.076073     0.095382  0.035587
# 45  RpPU  DLPFC_cTBS     M1_cTBS -0.059462  0.047292     0.105682  0.039429
# 46  RpPU  DLPFC_cTBS  DLPFC_20Hz -0.101992  0.074954      0.10732  0.040041
# 47  RpPU     M1_cTBS  DLPFC_20Hz -0.042531  0.027661      0.10732  0.040041
#
#    pval_Intercept pval_Slope
# 0        0.021498   0.000211
# 1        0.792552   0.798191
# 2        0.580926   0.415245
# 3         0.07153   0.000455
# 4        0.012616   0.000077
# 5        0.471623    0.61621
# 6        0.363386   0.083495
# 7        0.569352   0.232198
# 8         0.21809   0.039144
# 9        0.190851   0.009619
# 10       0.059187   0.000833
# 11        0.54937   0.428378
# 12       0.243208   0.004702
# 13       0.894373   0.589351
# 14       0.284847   0.204069
# 15       0.249986   0.002886
# 16       0.049111   0.000328
# 17       0.403825   0.510328
# 18       0.117069   0.004864
# 19       0.410496   0.210891
# 20        0.28066   0.058414
# 21       0.034388   0.000319
# 22       0.020087   0.000035
# 23       0.809145   0.554089
# 24       0.642968   0.070328
# 25       0.707592   0.254485
# 26       0.114377   0.087035
# 27       0.457934   0.009046
# 28        0.07073   0.001947
# 29       0.281799   0.597675
# 30       0.973256   0.921908
# 31        0.26498   0.074311
# 32        0.29985   0.096432
# 33       0.338615   0.095648
# 34       0.372281   0.118071
# 35       0.960055   0.937857
# 36       0.271405   0.009609
# 37        0.85646   0.857576
# 38       0.114216   0.160492
# 39          0.257   0.014255
# 40       0.018158   0.000458
# 41       0.212701   0.275318
# 42       0.746106   0.974415
# 43       0.337309   0.165365
# 44         0.1655   0.032543
# 45       0.573674   0.230366
# 46       0.341932   0.061215
# 47       0.691886   0.489671

# %% [markdown]
# ---

# %%
tmp = cm.turbo(np.linspace(0.1,1.0,4))
palette = [colors.rgb2hex(rgb, keep_alpha=False) for rgb in tmp][:-1]

colors.ListedColormap(palette)

# %%
palette = ['#A9A9A9', '#628dbd', '#C06C84', '#85cc6f']
cmap = colors.ListedColormap(palette)
cmap

# %% [markdown]
# ---

# %% [markdown]
# ## Fig. 3

# %%
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(12,6))
axs = np.reshape(axs, -1)

for ii, roi in enumerate(list_roi):
    ax = axs[ii]
    df_tmp = df_LME[(df_LME.roi==roi)&(df_LME.group_ref=='no_stim')]

    ## plotting figure
    ax.set_title('%s'%roi)

    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    ax.bar(
        [0,1,2],
        df_tmp.Slope, yerr=df_tmp.SE_Slope,
        capsize=5,
        color=palette[1:], alpha=0.7,
    )
    if ii == 0:
        ax.set_ylabel('Change in parameter estimates per 10 minutes (A.U.)', fontsize=14)
        
    ax.set_ylim([-0.25,0.21])
    yticks=[-0.2, -0.1, 0, 0.1, 0.2]
    ax.set_yticks(yticks)
    ax.set_yticklabels(yticks, fontsize=14)
    # ax.set_xticks([0, 1, 2])
    # ax.set_xticklabels(['', '', ''], fontsize=0)
    ax.tick_params(
        axis='x',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        labelbottom=False  # labels along the bottom edge are off
    )

# %%
for ii, group_ref in enumerate(list_group[1:][:-1]):
    for kk, roi in enumerate(list_roi):
        ax = axs[kk]
        for jj, group in enumerate(list_group[1:][ii+1:]):
            jj_ = ii + 1 + jj
            df_tmp = df_LME[(df_LME.roi==roi)&(df_LME.group_ref=='no_stim')&(df_LME.group==group)]
            pval = df_LME[(df_LME.roi==roi)&(df_LME.group_ref==group_ref)&(df_LME.group==group)].pval_Slope.values[0]
            y = df_tmp.Slope.values[0]
            se = df_tmp.SE_Slope.values[0]
            if pval < 0.05:
                print('(%s) %s vs. %s: %s%.3e'%(roi,group_ref,group,convert_pvalue_to_asterisks(pval),pval))
                ax.text(
                    jj_, min(y-se,0)-0.035,
                    convert_pvalue_to_asterisks(pval),
                    fontsize=16, color=cmap(jj_+1),
                    horizontalalignment='center', verticalalignment='center'
                )
                # ax.text(
                #     jj_, 0.1+0.05*(jj+1),
                #     '%.3f-%.3f'%(y,se),
                #     horizontalalignment='center', verticalalignment='center'
                # )
    print('')
fig
# Out:
# (LaCA) DLPFC_cTBS vs. M1_cTBS: ***4.552e-04
# (LaCA) DLPFC_cTBS vs. DLPFC_20Hz: ****7.701e-05
# (LpCA) DLPFC_cTBS vs. M1_cTBS: **9.619e-03
# (LpCA) DLPFC_cTBS vs. DLPFC_20Hz: ***8.328e-04
# (RaCA) DLPFC_cTBS vs. M1_cTBS: **2.886e-03
# (RaCA) DLPFC_cTBS vs. DLPFC_20Hz: ***3.276e-04
# (RpCA) DLPFC_cTBS vs. M1_cTBS: ***3.188e-04
# (RpCA) DLPFC_cTBS vs. DLPFC_20Hz: ****3.530e-05
# (LaPU) DLPFC_cTBS vs. M1_cTBS: **9.046e-03
# (LaPU) DLPFC_cTBS vs. DLPFC_20Hz: **1.947e-03
# (RaPU) DLPFC_cTBS vs. M1_cTBS: *1.426e-02
# (RaPU) DLPFC_cTBS vs. DLPFC_20Hz: ***4.579e-04

# %%
### legend
nax = fig.add_axes([0.25, 1, .8, 0.2])

for ii, group in enumerate(list_group[1:]):
    if group == 'DLPFC_cTBS':
        gg = 'DLPFC$_{cTBS}$'
    elif group == 'M1_cTBS':
        gg = 'M1$_{cTBS}$'
    elif group == 'DLPFC_20Hz':
        gg = 'DLPFC$_{20Hz}$'
        
    rgb = cmap(ii+1)
    dx = 0.25*ii
    x, y = 0 + dx, 0.02
    w, h = 0.045, 0.15
    nax.add_patch(Rectangle((x,y),w , h, facecolor=rgb, edgecolor='k'))
    nax.text(x+.085, 0, gg, fontsize=15, horizontalalignment='left', verticalalignment='bottom')
    
nax.axis('off')
fig.tight_layout()
fig
# Out:
# C:\Users\psb62\AppData\Local\Temp\ipykernel_5396\1613398458.py:20: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
fig.savefig(
    join(dir_home, 'Github/labs/GP/results/fig.3ii.png')
    , dpi=300, facecolor=[1,1,1,1]
    , bbox_inches = "tight"
)

# %% [markdown]
# ---

# %% [markdown]
# 2. beta ~ time*C(group, Treatment('%s'))*C(ROI, Treatment('%s'))

# %%
model = smf.mixedlm(
    "beta ~ time*C(group, Treatment('%s'))*C(striatum, Treatment('%s'))"%('no_stim','caudate'),
    df,
    groups=df['subj']
)
result = model.fit()
print(result.summary())
# Out:
#                                                   Mixed Linear Model Regression Results
# =========================================================================================================================================
# Model:                                        MixedLM                            Dependent Variable:                            beta
# No. Observations:                             1920                               Method:                                        REML
# No. Groups:                                   80                                 Scale:                                         0.0555
# Min. group size:                              24                                 Log-Likelihood:                                -113.2101
# Max. group size:                              24                                 Converged:                                     Yes
# Mean group size:                              24.0
# -----------------------------------------------------------------------------------------------------------------------------------------
#                                                                                                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                       0.524    0.054  9.658 0.000  0.418  0.631
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]                                                   -0.133    0.092 -1.449 0.147 -0.314  0.047
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]                                                    0.195    0.090  2.160 0.031  0.018  0.372
# C(group, Treatment('no_stim'))[T.M1_cTBS]                                                      -0.043    0.090 -0.471 0.638 -0.219  0.134
# C(striatum, Treatment('caudate'))[T.putamen]                                                    0.032    0.046  0.682 0.495 -0.059  0.123
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]:C(striatum, Treatment('caudate'))[T.putamen]      -0.023    0.079 -0.292 0.771 -0.177  0.131
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(striatum, Treatment('caudate'))[T.putamen]      -0.157    0.077 -2.039 0.041 -0.309 -0.006
# C(group, Treatment('no_stim'))[T.M1_cTBS]:C(striatum, Treatment('caudate'))[T.putamen]         -0.025    0.077 -0.322 0.747 -0.176  0.126
# time                                                                                           -0.122    0.015 -8.006 0.000 -0.152 -0.092
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]                                               0.076    0.026  2.957 0.003  0.026  0.127
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]                                              -0.135    0.025 -5.343 0.000 -0.185 -0.086
# time:C(group, Treatment('no_stim'))[T.M1_cTBS]                                                  0.040    0.025  1.592 0.111 -0.009  0.090
# time:C(striatum, Treatment('caudate'))[T.putamen]                                               0.016    0.021  0.740 0.459 -0.026  0.058
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]:C(striatum, Treatment('caudate'))[T.putamen] -0.006    0.036 -0.165 0.869 -0.077  0.065
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(striatum, Treatment('caudate'))[T.putamen]  0.087    0.036  2.435 0.015  0.017  0.157
# time:C(group, Treatment('no_stim'))[T.M1_cTBS]:C(striatum, Treatment('caudate'))[T.putamen]     0.004    0.036  0.116 0.908 -0.066  0.074
# Group Var                                                                                       0.056    0.041
# =========================================================================================================================================

# %%
for striatum in ['caudate','putamen']:
    print('*%s*'%striatum)
    df_tmp = df[df.striatum==striatum]

    ## LR
    print('*LR')
    model = smf.mixedlm(
        "beta ~ time*C(group, Treatment('%s'))*C(LR, Treatment('%s'))"%('no_stim','L'),
        df_tmp,
        groups=df_tmp['subj']
    )
    result = model.fit()
    for idx in result.fe_params.index:
        pval = result.pvalues[idx]
        if pval < 0.05:
            print('%s: %s%.3e'%(idx,convert_pvalue_to_asterisks(pval),pval))
        
    print(result.summary())

    ## AP
    print('*AP')
    model = smf.mixedlm(
        "beta ~ time*C(group, Treatment('%s'))*C(AP, Treatment('%s'))"%('no_stim','a'),
        df_tmp,
        groups=df_tmp['subj']
    )
    result = model.fit()
    for idx in result.fe_params.index:
        pval = result.pvalues[idx]
        if pval < 0.05:
            print('%s: %s%.3e'%(idx,convert_pvalue_to_asterisks(pval),pval))
    print(result.summary())
# Out:
# *caudate*
# *LR
# Intercept: ****6.427e-15
# time: ****4.833e-09
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]: *3.779e-02
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]: ***1.388e-04
#                                          Mixed Linear Model Regression Results
# =======================================================================================================================
# Model:                                   MixedLM                      Dependent Variable:                      beta
# No. Observations:                        960                          Method:                                  REML
# No. Groups:                              80                           Scale:                                   0.0532
# Min. group size:                         12                           Log-Likelihood:                          -98.9334
# Max. group size:                         12                           Converged:                               Yes
# Mean group size:                         12.0
# -----------------------------------------------------------------------------------------------------------------------
#                                                                              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                     0.520    0.067  7.795 0.000  0.389  0.651
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]                                 -0.123    0.113 -1.090 0.276 -0.345  0.098
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]                                  0.211    0.111  1.903 0.057 -0.006  0.429
# C(group, Treatment('no_stim'))[T.M1_cTBS]                                    -0.023    0.111 -0.203 0.839 -0.240  0.195
# C(LR, Treatment('L'))[T.R]                                                    0.009    0.064  0.135 0.893 -0.117  0.135
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]:C(LR, Treatment('L'))[T.R]      -0.020    0.109 -0.184 0.854 -0.234  0.194
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(LR, Treatment('L'))[T.R]      -0.032    0.107 -0.300 0.764 -0.242  0.177
# C(group, Treatment('no_stim'))[T.M1_cTBS]:C(LR, Treatment('L'))[T.R]         -0.040    0.107 -0.374 0.708 -0.250  0.170
# time                                                                         -0.123    0.021 -5.853 0.000 -0.164 -0.082
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]                             0.074    0.036  2.077 0.038  0.004  0.144
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]                            -0.133    0.035 -3.810 0.000 -0.202 -0.065
# time:C(group, Treatment('no_stim'))[T.M1_cTBS]                                0.037    0.035  1.055 0.291 -0.032  0.106
# time:C(LR, Treatment('L'))[T.R]                                               0.003    0.030  0.100 0.920 -0.055  0.061
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]:C(LR, Treatment('L'))[T.R]  0.004    0.050  0.082 0.935 -0.095  0.103
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(LR, Treatment('L'))[T.R] -0.003    0.050 -0.068 0.946 -0.100  0.094
# time:C(group, Treatment('no_stim'))[T.M1_cTBS]:C(LR, Treatment('L'))[T.R]     0.007    0.050  0.134 0.894 -0.090  0.104
# Group Var                                                                     0.071    0.056
# =======================================================================================================================
#
# *AP
# Intercept: ****3.867e-17
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]: *3.848e-02
# time: ****1.074e-06
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]: ****2.414e-06
#                                          Mixed Linear Model Regression Results
# =======================================================================================================================
# Model:                                   MixedLM                      Dependent Variable:                      beta
# No. Observations:                        960                          Method:                                  REML
# No. Groups:                              80                           Scale:                                   0.0479
# Min. group size:                         12                           Log-Likelihood:                          -53.5486
# Max. group size:                         12                           Converged:                               Yes
# Mean group size:                         12.0
# -----------------------------------------------------------------------------------------------------------------------
#                                                                              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                     0.549    0.065  8.417 0.000  0.421  0.677
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]                                 -0.108    0.111 -0.974 0.330 -0.325  0.109
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]                                  0.225    0.109  2.070 0.038  0.012  0.437
# C(group, Treatment('no_stim'))[T.M1_cTBS]                                     0.008    0.109  0.076 0.940 -0.204  0.221
# C(AP, Treatment('a'))[T.p]                                                   -0.050    0.061 -0.818 0.413 -0.170  0.070
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]:C(AP, Treatment('a'))[T.p]      -0.051    0.103 -0.495 0.621 -0.254  0.152
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(AP, Treatment('a'))[T.p]      -0.059    0.101 -0.583 0.560 -0.258  0.140
# C(group, Treatment('no_stim'))[T.M1_cTBS]:C(AP, Treatment('a'))[T.p]         -0.101    0.101 -1.000 0.317 -0.300  0.097
# time                                                                         -0.097    0.020 -4.878 0.000 -0.137 -0.058
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]                             0.051    0.034  1.506 0.132 -0.015  0.117
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]                            -0.157    0.033 -4.715 0.000 -0.222 -0.092
# time:C(group, Treatment('no_stim'))[T.M1_cTBS]                                0.019    0.033  0.575 0.566 -0.046  0.084
# time:C(AP, Treatment('a'))[T.p]                                              -0.049    0.028 -1.718 0.086 -0.104  0.007
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]:C(AP, Treatment('a'))[T.p]  0.050    0.048  1.052 0.293 -0.043  0.144
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(AP, Treatment('a'))[T.p]  0.043    0.047  0.919 0.358 -0.049  0.135
# time:C(group, Treatment('no_stim'))[T.M1_cTBS]:C(AP, Treatment('a'))[T.p]     0.042    0.047  0.901 0.368 -0.050  0.134
# Group Var                                                                     0.072    0.059
# =======================================================================================================================
#
# *putamen*
# *LR
# Intercept: ****1.037e-20
# time: ****1.050e-08
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]: *3.872e-02
#                                          Mixed Linear Model Regression Results
# =======================================================================================================================
# Model:                                   MixedLM                      Dependent Variable:                      beta
# No. Observations:                        960                          Method:                                  REML
# No. Groups:                              80                           Scale:                                   0.0521
# Min. group size:                         12                           Log-Likelihood:                          -75.1474
# Max. group size:                         12                           Converged:                               Yes
# Mean group size:                         12.0
# -----------------------------------------------------------------------------------------------------------------------
#                                                                              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                     0.559    0.060  9.332 0.000  0.442  0.677
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]                                 -0.155    0.102 -1.525 0.127 -0.354  0.044
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]                                  0.028    0.100  0.278 0.781 -0.168  0.223
# C(group, Treatment('no_stim'))[T.M1_cTBS]                                    -0.080    0.100 -0.799 0.424 -0.275  0.116
# C(LR, Treatment('L'))[T.R]                                                   -0.006    0.064 -0.100 0.920 -0.131  0.118
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]:C(LR, Treatment('L'))[T.R]      -0.003    0.108 -0.027 0.979 -0.214  0.209
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(LR, Treatment('L'))[T.R]       0.020    0.106  0.187 0.852 -0.188  0.227
# C(group, Treatment('no_stim'))[T.M1_cTBS]:C(LR, Treatment('L'))[T.R]          0.024    0.106  0.231 0.817 -0.183  0.232
# time                                                                         -0.119    0.021 -5.722 0.000 -0.160 -0.078
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]                             0.073    0.035  2.067 0.039  0.004  0.142
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]                            -0.043    0.035 -1.254 0.210 -0.111  0.024
# time:C(group, Treatment('no_stim'))[T.M1_cTBS]                                0.061    0.035  1.757 0.079 -0.007  0.129
# time:C(LR, Treatment('L'))[T.R]                                               0.027    0.029  0.912 0.362 -0.031  0.085
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]:C(LR, Treatment('L'))[T.R] -0.006    0.050 -0.113 0.910 -0.104  0.092
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(LR, Treatment('L'))[T.R] -0.009    0.049 -0.186 0.853 -0.105  0.087
# time:C(group, Treatment('no_stim'))[T.M1_cTBS]:C(LR, Treatment('L'))[T.R]    -0.033    0.049 -0.673 0.501 -0.129  0.063
# Group Var                                                                     0.047    0.038
# =======================================================================================================================
#
# *AP
# Intercept: ****2.182e-39
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]: *3.518e-02
# C(AP, Treatment('a'))[T.p]: ****1.390e-09
# time: ****1.875e-11
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]: *1.508e-02
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]: ***7.257e-04
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(AP, Treatment('a'))[T.p]: *1.848e-02
#                                          Mixed Linear Model Regression Results
# =======================================================================================================================
# Model:                                   MixedLM                      Dependent Variable:                      beta
# No. Observations:                        960                          Method:                                  REML
# No. Groups:                              80                           Scale:                                   0.0340
# Min. group size:                         12                           Log-Likelihood:                          109.6218
# Max. group size:                         12                           Converged:                               Yes
# Mean group size:                         12.0
# -----------------------------------------------------------------------------------------------------------------------
#                                                                              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                     0.712    0.054 13.131 0.000  0.606  0.818
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]                                 -0.194    0.092 -2.106 0.035 -0.374 -0.013
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]                                  0.092    0.090  1.020 0.308 -0.085  0.269
# C(group, Treatment('no_stim'))[T.M1_cTBS]                                    -0.034    0.090 -0.378 0.706 -0.211  0.143
# C(AP, Treatment('a'))[T.p]                                                   -0.312    0.051 -6.057 0.000 -0.412 -0.211
# C(group, Treatment('no_stim'))[T.DLPFC_20Hz]:C(AP, Treatment('a'))[T.p]       0.074    0.087  0.854 0.393 -0.097  0.245
# C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(AP, Treatment('a'))[T.p]      -0.109    0.086 -1.271 0.204 -0.276  0.059
# C(group, Treatment('no_stim'))[T.M1_cTBS]:C(AP, Treatment('a'))[T.p]         -0.067    0.086 -0.780 0.436 -0.234  0.101
# time                                                                         -0.113    0.017 -6.715 0.000 -0.146 -0.080
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]                             0.069    0.029  2.430 0.015  0.013  0.125
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]                            -0.095    0.028 -3.380 0.001 -0.150 -0.040
# time:C(group, Treatment('no_stim'))[T.M1_cTBS]                                0.030    0.028  1.065 0.287 -0.025  0.085
# time:C(AP, Treatment('a'))[T.p]                                               0.015    0.024  0.613 0.540 -0.032  0.061
# time:C(group, Treatment('no_stim'))[T.DLPFC_20Hz]:C(AP, Treatment('a'))[T.p]  0.002    0.040  0.040 0.968 -0.078  0.081
# time:C(group, Treatment('no_stim'))[T.DLPFC_cTBS]:C(AP, Treatment('a'))[T.p]  0.093    0.040  2.356 0.018  0.016  0.171
# time:C(group, Treatment('no_stim'))[T.M1_cTBS]:C(AP, Treatment('a'))[T.p]     0.029    0.040  0.734 0.463 -0.049  0.107
# Group Var                                                                     0.048    0.047
# =======================================================================================================================
