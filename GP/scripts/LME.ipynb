# %%
# from pymer4.models import Lmer
# from statsmodels.formula.api import ols
# from statsmodels.stats.multitest import multipletests

# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import statsmodels.api as sm
# import statsmodels.formula.api as smf

# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
rois_left = ['laPU', 'laCA', 'lpPU', 'lpCA']
rois_right = ['raPU', 'raCA', 'rpPU', 'rpCA']
rois_PU = ['laPU','raPU','lpPU','rpPU']
rois_CA = ['laCA','raCA','lpCA','rpCA']
rois_ant = ['laPU', 'laCA', 'raPU', 'raCA']
rois_post = ['lpPU', 'lpCA', 'rpPU', 'rpCA']

# %%
list_roi = rois_CA + rois_PU

# %%
list_group = np.array(['baseline', 'DLPFC_cTBS', 'M1_cTBS', 'DLPFC_20Hz'])

# %%
def convert_pvalue_to_asterisks(pvalue):
    if pvalue <= 0.0001:
        return "****"
    elif pvalue <= 0.001:
        return "***"
    elif pvalue <= 0.01:
        return "**"
    elif pvalue <= 0.05:
        return "*"
    return "ns"

# %%
df_n50 = pd.read_excel('./KJH/LME/data/Rew#1_Coef_GPn50_KJH.xlsx')
df_n50['stim'] = ['yes' if subj[1]!='A' else 'no' for subj in df_n50.subj]
df_n50
# Out:
#       subj       group  run   roi      beta  time stim
# 0     GA01    baseline  r01  raPU  0.518611     0   no
# 1     GA01    baseline  r01  laPU  0.599993     0   no
# 2     GA01    baseline  r01  lpPU  0.151185     0   no
# 3     GA01    baseline  r01  rpPU  0.272298     0   no
# 4     GA01    baseline  r01  laCA  0.538827     0   no
# ...    ...         ...  ...   ...       ...   ...  ...
# 1915  GP75  DLPFC_20Hz  r03  rpPU  0.614432     2  yes
# 1916  GP75  DLPFC_20Hz  r03  laCA  0.917109     2  yes
# 1917  GP75  DLPFC_20Hz  r03  lpCA  0.538714     2  yes
# 1918  GP75  DLPFC_20Hz  r03  raCA  1.086447     2  yes
# 1919  GP75  DLPFC_20Hz  r03  rpCA  0.616211     2  yes
#
# [1920 rows x 7 columns]

# %% [markdown]
# **Hierarchical Structure**
#
# - level 1: subject (GA01 ~ GP75); this is the "$i$" in the equation.
# - level 2: group (baseline ~ DLPFC_20Hz); this is the "$j$" in the equation.
# - level 3: TMS (no stim vs stim); This level is not modeled in the LMM equation.

# %%
# # Check the rest of new data (data before GP71) is the same as the old data.
# df = pd.read_excel('./data/Rew#1_Coef_filtered_new_KJH.xlsx')
# merged_df = pd.merge(df, df_n50, on=['subj', 'group', 'run', 'roi', 'time'], suffixes=('_1', '_n50'))
# merged_df['beta_same'] = merged_df['beta_1'] == merged_df['beta_n50']
# all(merged_df['beta_same'])

# %%
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# ## Note

# %% [markdown]
# StatsModels formula api uses `Patsy` to handle passing the formulas. The pseudo code looks like the following:
# ```
# smf.mixedlm("dependent_variable ~ independent_variable1 + independent_variable2 + independent_variablen", data = df).fit()
# ```
#
# To tell the model that a variable is categorical, it needs to be wrapped in C(independent_variable). The pseudo code with a categorical independent variable looks like:
# ```
# smf.mixedlm("dependent_variable ~ independent_variable1 + C(independent_variable2)", data = df).fit()
# ```
#
# By default, `Patsy` chooses the first categorical variable as the reference category; it's possible to change the reference category if desired. In order to do this, one needs to specify the reference category while one is specifying the variable is a categorical variable. Pseduo code is as follows:
# ```
# smf.mixedlm("dependent_variable ~ independent_variable1 + C(independent_variable2, Treatment(categorical_group))", data = df).fit()
# ```
#
# Where categorical_group is the desired reference group.
#
# [pythonfordatascience](https://www.pythonfordatascience.org/mixed-effects-regression-python/#:~:text=Mixed%20effect%20models%20are%20also%20known%20as)

# %% [markdown]
# ---

# %% [markdown]
# ### Random Intercept Model

# %% [markdown]
# 1. $\beta \sim time + (1|subject)$ or $\beta \sim time + 1$ or $\beta \sim time$ ; These are the same notation
#
# $1$ means a random intercept
# - fixed effect : **time**
# - randome effect : **subject** (*no-stim* group)

# %% [markdown]
# ### linear mixed-effects (LME) model to examine the fMRI activity over time for the 'No-stim' group.

# %%
roi = 'laPU'
df_tmp = df_n50[(df_n50['group']=='baseline')&(df_n50['roi']==roi)]
# df_tmp = df_tmp.sample(frac=1).reset_index(drop=True)
model = smf.mixedlm("beta ~ time", df_tmp, groups=df_tmp['subj'])
result = model.fit()
print('%s (dof=%d)'%(roi,result.df_resid))
print(result.summary())

palette = sns.color_palette("deep", len(df_tmp.group.unique()))

g = sns.swarmplot(
    data=df_tmp,
    x='time', y='beta', hue='group', palette=palette
)
g.legend(title='')
x = np.array([0,1,2])
y = x * result.params.time + result.params.Intercept

g.plot(
    x,y,
    label='slope=%.4f'%result.params.time,
    linestyle='--', linewidth=2,
    color=palette[0]
)
# Out:
# laPU (dof=88)
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: beta
# No. Observations: 90      Method:             REML
# No. Groups:       30      Scale:              0.0602
# Min. group size:  3       Log-Likelihood:     -29.8122
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.601    0.068  8.893 0.000  0.469  0.734
# time        -0.133    0.032 -4.198 0.000 -0.195 -0.071
# Group Var    0.087    0.140
# ======================================================

# %% [markdown]
# **Intercept** : This represents the baseline value of the dependent variable (=$\beta$) when all other predictors are zero (when *time*=0 and *group=baseline*; the reference group). It is the starting point of the model.
#
# **time** : This represents the effect of *time* on $\beta$. It shows how $\beta$ changes over *time*.

# %%
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(12,6))
axs = np.reshape(axs, -1)
palette = sns.color_palette("hls", len(list_roi))
x = np.array([0,1,2])

for ii, roi in enumerate(list_roi):
    ax = axs[ii]
    df_tmp = df_n50[(df_n50['group']=='baseline')&(df_n50['roi']==roi)]
    model = smf.mixedlm("beta ~ time + 1", df_tmp, groups=df_tmp['subj'])
    result = model.fit()
    pval = result.pvalues.time
    # print(result.summary())

    y = x * result.params.time + result.params.Intercept
    ax.plot(
        x,y,
        label='slope=%.4f'%result.params.time,
        linestyle='--', linewidth=2,
        color=palette[ii]
    )
    # g = sns.swarmplot(
    #     data=df_tmp,
    #     x='time', y='beta', color=palette[ii],
    #     ax=ax
    # )
    g = sns.violinplot(
        data=df_tmp,
        x='time', y='beta', color=palette[ii],
        alpha = 0.5,
        ax=ax
    )
    g.legend().remove()
    g.set_xticks([0, 1, 2])
    g.set_xticklabels(['10 min', '20 min', '30 min'], fontsize=12)
    g.set_xlabel('', fontsize=0)

    g.tick_params(axis='y', labelsize=12)
    g.set_ylim([-2, 2])
    g.set_ylabel('', fontsize=0)
    
    # *8 means a correction (8 ROIs)
    pval_c = pval * 8

    roi_ = roi[0].upper()+roi[1:]
    g.set_title('%s%s'%(convert_pvalue_to_asterisks(pval), roi_), fontsize=14)
    print('%s (dof=%d): %sp=%.4f uncorrected / %sp=%.4f corrected'%
        (roi, result.df_resid, convert_pvalue_to_asterisks(pval), pval, convert_pvalue_to_asterisks(pval_c), pval_c)
    )

fig.text(-.015, 0.5, 'Performance-Modulated Activity (A.U.)', va='center', rotation='vertical', fontsize=18)

fig.tight_layout()
# Out:
# laCA (dof=88): **p=0.0041 uncorrected / *p=0.0326 corrected
# raCA (dof=88): **p=0.0011 uncorrected / **p=0.0084 corrected
# lpCA (dof=88): ****p=0.0000 uncorrected / ***p=0.0002 corrected
# rpCA (dof=88): ***p=0.0001 uncorrected / **p=0.0012 corrected
# laPU (dof=88): ****p=0.0000 uncorrected / ***p=0.0002 corrected
# raPU (dof=88): ***p=0.0007 uncorrected / **p=0.0056 corrected
# lpPU (dof=88): ***p=0.0002 uncorrected / **p=0.0014 corrected
# rpPU (dof=88): ***p=0.0004 uncorrected / **p=0.0031 corrected

# %%
fig.savefig(
    '/home/sungbeenpark/Github/labs/GP/results/fig.S1b.png'
    , dpi=300, facecolor=[1,1,1,1]
    , bbox_inches = "tight"
)

# %% [markdown]
# 2. $\beta \sim time * group + (1|sujbect)$ or $\beta \sim time + C(group, Treatment(reference)) + time:C(group, Treatment(reference))$
# - fixed effect : **time**, **group** (possibly correlated)
# - random effect : **subject**

# %%
from matplotlib import cm, colors, patches, lines

# palette = sns.color_palette("deep", len(df_tmp.group.unique()))
palette = ["#000000", "#1f77b4", "#ff7f0e", "#2ca02c"]
cmap = colors.ListedColormap(palette)
cmap

# %% [markdown]
# i) Reference group = No-stim

# %%
group_ref = 'baseline'

# %%
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(12,6))
axs = np.reshape(axs, -1)
palette = sns.color_palette("deep", len(list_roi))
x = np.array([0,1,2])

print('Reference Group = %s\n'%group_ref)
for ii, roi in enumerate(list_roi):
    ax = axs[ii]
    df_tmp = df_n50[df_n50['roi']==roi]
    model = smf.mixedlm(
        "beta ~ time + C(group, Treatment('%s')) + time:C(group, Treatment('%s'))"%(group_ref,group_ref),
        df_tmp,
        groups=df_tmp['subj']
    )
    result = model.fit()

    ## plotting figure
    y = x * result.params.time + result.params.Intercept
    ax.plot(
        x,y,
        label='slope=%.4f'%result.params.time,
        linestyle='--', linewidth=2,
        color=palette[0] # No-stim
    )
    
    # *8 means a correction (8 ROIs)
    pval = result.pvalues.time*8
    ax.set_title('%s (corrected %sp=%.4f)'%(roi, convert_pvalue_to_asterisks(pval), pval))
    
    g = sns.swarmplot(
        data=df_tmp,
        x='time', y='beta', hue='group', hue_order=list_group,
        size=3,
        # color=palette[ii],
        ax=ax
    )
    g.legend().remove()
    # ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    g.set_xticks([0, 1, 2])
    g.set_xticklabels(['10 min', '20 min', '30 min'])
    g.set_xlabel('', fontsize=0)

    g.set_ylim([-1,1.5])

    cnt = 0
    for gg in list_group[list_group != group_ref]:
        ss = "time:C(group, Treatment('%s'))[T.%s]"%(group_ref,gg)
        pval = result.pvalues[ss]
        pval_c = pval * 8  # '*8' is a correction factor
        if pval < 0.05:
            print('%s (dof=%d)'%(roi,result.df_resid))
            print('%s -> %s : %sp=%.5f uncorrected / %sp=%.5f corrected'%
                (group_ref,gg,convert_pvalue_to_asterisks(pval),pval,convert_pvalue_to_asterisks(pval_c),pval_c)
            )
            cnt += 1
    if cnt > 0:
        print(result.summary())

fig.tight_layout()
# Out:
# Reference Group = baseline
#
# laCA (dof=232)
# baseline -> DLPFC_cTBS : ***p=0.00021 uncorrected / **p=0.00169 corrected
#                             Mixed Linear Model Regression Results
# =============================================================================================
# Model:                         MixedLM              Dependent Variable:              beta
# No. Observations:              240                  Method:                          REML
# No. Groups:                    80                   Scale:                           0.0498
# Min. group size:               3                    Log-Likelihood:                  -56.6084
# Max. group size:               3                    Converged:                       Yes
# Mean group size:               3.0
# ---------------------------------------------------------------------------------------------
#                                                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                           0.426    0.059  7.185 0.000  0.310  0.542
# C(group, Treatment('baseline'))[T.DLPFC_20Hz]      -0.033    0.100 -0.326 0.745 -0.230  0.164
# C(group, Treatment('baseline'))[T.DLPFC_cTBS]       0.119    0.099  1.204 0.228 -0.074  0.312
# C(group, Treatment('baseline'))[T.M1_cTBS]          0.046    0.099  0.468 0.640 -0.147  0.239
# time                                               -0.087    0.029 -3.017 0.003 -0.143 -0.030
# time:C(group, Treatment('baseline'))[T.DLPFC_20Hz]  0.040    0.049  0.815 0.415 -0.056  0.136
# time:C(group, Treatment('baseline'))[T.DLPFC_cTBS] -0.177    0.048 -3.705 0.000 -0.271 -0.084
# time:C(group, Treatment('baseline'))[T.M1_cTBS]     0.012    0.048  0.256 0.798 -0.082  0.106
# Group Var                                           0.064    0.071
# =============================================================================================
#
# raCA (dof=232)
# baseline -> DLPFC_cTBS : **p=0.00470 uncorrected / *p=0.03762 corrected
#                             Mixed Linear Model Regression Results
# =============================================================================================
# Model:                         MixedLM              Dependent Variable:              beta
# No. Observations:              240                  Method:                          REML
# No. Groups:                    80                   Scale:                           0.0501
# Min. group size:               3                    Log-Likelihood:                  -59.8423
# Max. group size:               3                    Converged:                       Yes
# Mean group size:               3.0
# ---------------------------------------------------------------------------------------------
#                                                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                           0.478    0.061  7.838 0.000  0.358  0.598
# C(group, Treatment('baseline'))[T.DLPFC_20Hz]      -0.081    0.103 -0.782 0.434 -0.284  0.122
# C(group, Treatment('baseline'))[T.DLPFC_cTBS]       0.017    0.101  0.170 0.865 -0.181  0.216
# C(group, Treatment('baseline'))[T.M1_cTBS]          0.009    0.101  0.084 0.933 -0.190  0.207
# time                                               -0.108    0.029 -3.738 0.000 -0.165 -0.051
# time:C(group, Treatment('baseline'))[T.DLPFC_20Hz]  0.062    0.049  1.270 0.204 -0.034  0.158
# time:C(group, Treatment('baseline'))[T.DLPFC_cTBS] -0.136    0.048 -2.827 0.005 -0.230 -0.042
# time:C(group, Treatment('baseline'))[T.M1_cTBS]     0.026    0.048  0.540 0.589 -0.068  0.120
# Group Var                                           0.070    0.076
# =============================================================================================
#
# lpCA (dof=232)
# baseline -> DLPFC_20Hz : *p=0.03914 uncorrected / nsp=0.31315 corrected
#                             Mixed Linear Model Regression Results
# =============================================================================================
# Model:                         MixedLM              Dependent Variable:              beta
# No. Observations:              240                  Method:                          REML
# No. Groups:                    80                   Scale:                           0.0577
# Min. group size:               3                    Log-Likelihood:                  -73.7685
# Max. group size:               3                    Converged:                       Yes
# Mean group size:               3.0
# ---------------------------------------------------------------------------------------------
#                                                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                           0.368    0.064  5.766 0.000  0.243  0.493
# C(group, Treatment('baseline'))[T.DLPFC_20Hz]      -0.066    0.108 -0.607 0.544 -0.278  0.146
# C(group, Treatment('baseline'))[T.DLPFC_cTBS]       0.037    0.106  0.347 0.729 -0.171  0.245
# C(group, Treatment('baseline'))[T.M1_cTBS]         -0.017    0.106 -0.163 0.871 -0.225  0.191
# time                                               -0.160    0.031 -5.143 0.000 -0.220 -0.099
# time:C(group, Treatment('baseline'))[T.DLPFC_20Hz]  0.108    0.053  2.063 0.039  0.005  0.212
# time:C(group, Treatment('baseline'))[T.DLPFC_cTBS] -0.089    0.052 -1.731 0.083 -0.190  0.012
# time:C(group, Treatment('baseline'))[T.M1_cTBS]     0.062    0.052  1.195 0.232 -0.039  0.163
# Group Var                                           0.074    0.077
# =============================================================================================
#
# rpCA (dof=232)
# baseline -> DLPFC_cTBS : **p=0.00486 uncorrected / *p=0.03891 corrected
#                             Mixed Linear Model Regression Results
# =============================================================================================
# Model:                         MixedLM              Dependent Variable:              beta
# No. Observations:              240                  Method:                          REML
# No. Groups:                    80                   Scale:                           0.0519
# Min. group size:               3                    Log-Likelihood:                  -60.3881
# Max. group size:               3                    Converged:                       Yes
# Mean group size:               3.0
# ---------------------------------------------------------------------------------------------
#                                                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                           0.339    0.060  5.660 0.000  0.222  0.456
# C(group, Treatment('baseline'))[T.DLPFC_20Hz]      -0.049    0.102 -0.487 0.626 -0.249  0.150
# C(group, Treatment('baseline'))[T.DLPFC_cTBS]       0.067    0.100  0.675 0.500 -0.128  0.262
# C(group, Treatment('baseline'))[T.M1_cTBS]         -0.046    0.100 -0.466 0.641 -0.242  0.149
# time                                               -0.132    0.029 -4.504 0.000 -0.190 -0.075
# time:C(group, Treatment('baseline'))[T.DLPFC_20Hz]  0.094    0.050  1.893 0.058 -0.003  0.192
# time:C(group, Treatment('baseline'))[T.DLPFC_cTBS] -0.138    0.049 -2.816 0.005 -0.233 -0.042
# time:C(group, Treatment('baseline'))[T.M1_cTBS]     0.061    0.049  1.251 0.211 -0.035  0.157
# Group Var                                           0.064    0.071
# =============================================================================================
#
# raPU (dof=232)
# baseline -> DLPFC_cTBS : **p=0.00961 uncorrected / nsp=0.07688 corrected
#                             Mixed Linear Model Regression Results
# =============================================================================================
# Model:                         MixedLM              Dependent Variable:              beta
# No. Observations:              240                  Method:                          REML
# No. Groups:                    80                   Scale:                           0.0365
# Min. group size:               3                    Log-Likelihood:                  -25.7894
# Max. group size:               3                    Converged:                       Yes
# Mean group size:               3.0
# ---------------------------------------------------------------------------------------------
#                                                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                           0.596    0.054 11.144 0.000  0.491  0.701
# C(group, Treatment('baseline'))[T.DLPFC_20Hz]      -0.125    0.091 -1.374 0.169 -0.302  0.053
# C(group, Treatment('baseline'))[T.DLPFC_cTBS]       0.019    0.089  0.214 0.831 -0.155  0.193
# C(group, Treatment('baseline'))[T.M1_cTBS]         -0.013    0.089 -0.149 0.882 -0.188  0.161
# time                                               -0.093    0.025 -3.778 0.000 -0.142 -0.045
# time:C(group, Treatment('baseline'))[T.DLPFC_20Hz]  0.059    0.042  1.403 0.160 -0.023  0.141
# time:C(group, Treatment('baseline'))[T.DLPFC_cTBS] -0.106    0.041 -2.590 0.010 -0.187 -0.026
# time:C(group, Treatment('baseline'))[T.M1_cTBS]     0.007    0.041  0.179 0.858 -0.073  0.088
# Group Var                                           0.055    0.070
# =============================================================================================
#
# rpPU (dof=232)
# baseline -> DLPFC_20Hz : *p=0.03254 uncorrected / nsp=0.26034 corrected
#                             Mixed Linear Model Regression Results
# =============================================================================================
# Model:                          MixedLM              Dependent Variable:              beta
# No. Observations:               240                  Method:                          REML
# No. Groups:                     80                   Scale:                           0.0264
# Min. group size:                3                    Log-Likelihood:                  17.4269
# Max. group size:                3                    Converged:                       Yes
# Mean group size:                3.0
# ---------------------------------------------------------------------------------------------
#                                                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                           0.325    0.043  7.565 0.000  0.241  0.409
# C(group, Treatment('baseline'))[T.DLPFC_20Hz]      -0.056    0.073 -0.772 0.440 -0.199  0.086
# C(group, Treatment('baseline'))[T.DLPFC_cTBS]      -0.029    0.071 -0.409 0.683 -0.169  0.111
# C(group, Treatment('baseline'))[T.M1_cTBS]         -0.041    0.071 -0.579 0.563 -0.181  0.099
# time                                               -0.092    0.021 -4.363 0.000 -0.133 -0.050
# time:C(group, Treatment('baseline'))[T.DLPFC_20Hz]  0.076    0.036  2.138 0.033  0.006  0.146
# time:C(group, Treatment('baseline'))[T.DLPFC_cTBS]  0.001    0.035  0.032 0.974 -0.067  0.070
# time:C(group, Treatment('baseline'))[T.M1_cTBS]     0.048    0.035  1.387 0.165 -0.020  0.117
# Group Var                                           0.033    0.051
# =============================================================================================

# %% [markdown]
# **C(group, Treatment('baseline'))[T.DLPFC_cTBS]** : This indicates the effect of the *DLPFC$_{cTBS}$* group compared to the *reference group*. It shows how being in the *baseline* group changes $\beta$.
#
# **time:C(group, Treatment('baseline'))[T.DLPFC_cTBS]** : This interaction term shows how the effect of *time* on $\beta$ differs between the *DLPFC$_{cTBS}$* group and the reference group (=*baseline*). It indicates whether the *time* effect is different for the *baseline* group.

# %% [markdown]
# ii) Reference group = DLPFC$_{20Hz}$

# %%
group_ref = 'DLPFC_20Hz'

# %%
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(12,6))
axs = np.reshape(axs, -1)
palette = sns.color_palette("deep", len(list_roi))
x = np.array([0,1,2])

print('Reference Group = %s\n'%group_ref)
for ii, roi in enumerate(list_roi):
    ax = axs[ii]
    df_tmp = df_n50[df_n50['roi']==roi]
    model = smf.mixedlm(
        "beta ~ time + C(group, Treatment('%s')) + time:C(group, Treatment('%s'))"%(group_ref,group_ref),
        df_tmp,
        groups=df_tmp['subj']
    )
    result = model.fit()

    ## plotting figure
    y = x * result.params.time + result.params.Intercept
    ax.plot(
        x,y,
        label='slope=%.4f'%result.params.time,
        linestyle='--', linewidth=2,
        color=palette[0] # No-stim
    )
    
    # *8 means a correction (8 ROIs)
    pval = result.pvalues.time*8
    ax.set_title('%s (corrected %sp=%.4f)'%(roi, convert_pvalue_to_asterisks(pval), pval))
    
    g = sns.swarmplot(
        data=df_tmp,
        x='time', y='beta', hue='group', hue_order=list_group,
        size=3,
        # color=palette[ii],
        ax=ax
    )
    g.legend().remove()
    # ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    g.set_xticks([0, 1, 2])
    g.set_xticklabels(['10 min', '20 min', '30 min'])
    g.set_xlabel('', fontsize=0)

    g.set_ylim([-1,1.5])

    cnt = 0
    for gg in list_group[list_group != group_ref]:
        ss = "time:C(group, Treatment('%s'))[T.%s]"%(group_ref,gg)
        pval = result.pvalues[ss]
        pval_c = pval * 8  # '*8' is a correction factor
        if pval < 0.05:
            print('%s (dof=%d)'%(roi,result.df_resid))
            print('%s -> %s : %sp=%.5f uncorrected / %sp=%.5f corrected'%
                (group_ref,gg,convert_pvalue_to_asterisks(pval),pval,convert_pvalue_to_asterisks(pval_c),pval_c)
            )
            cnt += 1
    if cnt > 0:
        print(result.summary())

fig.tight_layout()
# Out:
# Reference Group = DLPFC_20Hz
#
# laCA (dof=232)
# DLPFC_20Hz -> DLPFC_cTBS : ****p=0.00008 uncorrected / ***p=0.00062 corrected
#                              Mixed Linear Model Regression Results
# ===============================================================================================
# Model:                           MixedLM              Dependent Variable:              beta
# No. Observations:                240                  Method:                          REML
# No. Groups:                      80                   Scale:                           0.0498
# Min. group size:                 3                    Log-Likelihood:                  -56.6084
# Max. group size:                 3                    Converged:                       Yes
# Mean group size:                 3.0
# -----------------------------------------------------------------------------------------------
#                                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                             0.393    0.081  4.844 0.000  0.234  0.552
# C(group, Treatment('DLPFC_20Hz'))[T.DLPFC_cTBS]       0.151    0.113  1.339 0.181 -0.070  0.373
# C(group, Treatment('DLPFC_20Hz'))[T.M1_cTBS]          0.079    0.113  0.697 0.486 -0.143  0.300
# C(group, Treatment('DLPFC_20Hz'))[T.baseline]         0.033    0.100  0.326 0.745 -0.164  0.230
# time                                                 -0.047    0.039 -1.194 0.232 -0.124  0.030
# time:C(group, Treatment('DLPFC_20Hz'))[T.DLPFC_cTBS] -0.217    0.055 -3.954 0.000 -0.325 -0.110
# time:C(group, Treatment('DLPFC_20Hz'))[T.M1_cTBS]    -0.028    0.055 -0.501 0.616 -0.135  0.080
# time:C(group, Treatment('DLPFC_20Hz'))[T.baseline]   -0.040    0.049 -0.815 0.415 -0.136  0.056
# Group Var                                             0.064    0.071
# ===============================================================================================
#
# raCA (dof=232)
# DLPFC_20Hz -> DLPFC_cTBS : ***p=0.00033 uncorrected / **p=0.00262 corrected
#                              Mixed Linear Model Regression Results
# ===============================================================================================
# Model:                           MixedLM              Dependent Variable:              beta
# No. Observations:                240                  Method:                          REML
# No. Groups:                      80                   Scale:                           0.0501
# Min. group size:                 3                    Log-Likelihood:                  -59.8423
# Max. group size:                 3                    Converged:                       Yes
# Mean group size:                 3.0
# -----------------------------------------------------------------------------------------------
#                                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                             0.397    0.084  4.756 0.000  0.233  0.561
# C(group, Treatment('DLPFC_20Hz'))[T.DLPFC_cTBS]       0.098    0.116  0.843 0.399 -0.130  0.326
# C(group, Treatment('DLPFC_20Hz'))[T.M1_cTBS]          0.089    0.116  0.768 0.442 -0.139  0.317
# C(group, Treatment('DLPFC_20Hz'))[T.baseline]         0.081    0.103  0.782 0.434 -0.122  0.284
# time                                                 -0.046    0.040 -1.157 0.247 -0.123  0.032
# time:C(group, Treatment('DLPFC_20Hz'))[T.DLPFC_cTBS] -0.198    0.055 -3.592 0.000 -0.306 -0.090
# time:C(group, Treatment('DLPFC_20Hz'))[T.M1_cTBS]    -0.036    0.055 -0.658 0.510 -0.144  0.072
# time:C(group, Treatment('DLPFC_20Hz'))[T.baseline]   -0.062    0.049 -1.270 0.204 -0.158  0.034
# Group Var                                             0.070    0.076
# ===============================================================================================
#
# lpCA (dof=232)
# DLPFC_20Hz -> baseline : *p=0.03914 uncorrected / nsp=0.31315 corrected
# lpCA (dof=232)
# DLPFC_20Hz -> DLPFC_cTBS : ***p=0.00083 uncorrected / **p=0.00666 corrected
#                              Mixed Linear Model Regression Results
# ===============================================================================================
# Model:                           MixedLM              Dependent Variable:              beta
# No. Observations:                240                  Method:                          REML
# No. Groups:                      80                   Scale:                           0.0577
# Min. group size:                 3                    Log-Likelihood:                  -73.7685
# Max. group size:                 3                    Converged:                       Yes
# Mean group size:                 3.0
# -----------------------------------------------------------------------------------------------
#                                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                             0.302    0.087  3.459 0.001  0.131  0.473
# C(group, Treatment('DLPFC_20Hz'))[T.DLPFC_cTBS]       0.102    0.122  0.842 0.400 -0.136  0.341
# C(group, Treatment('DLPFC_20Hz'))[T.M1_cTBS]          0.048    0.122  0.398 0.691 -0.190  0.287
# C(group, Treatment('DLPFC_20Hz'))[T.baseline]         0.066    0.108  0.607 0.544 -0.146  0.278
# time                                                 -0.051    0.042 -1.201 0.230 -0.134  0.032
# time:C(group, Treatment('DLPFC_20Hz'))[T.DLPFC_cTBS] -0.198    0.059 -3.342 0.001 -0.314 -0.082
# time:C(group, Treatment('DLPFC_20Hz'))[T.M1_cTBS]    -0.047    0.059 -0.792 0.428 -0.163  0.069
# time:C(group, Treatment('DLPFC_20Hz'))[T.baseline]   -0.108    0.053 -2.063 0.039 -0.212 -0.005
# Group Var                                             0.074    0.077
# ===============================================================================================
#
# rpCA (dof=232)
# DLPFC_20Hz -> DLPFC_cTBS : ****p=0.00004 uncorrected / ***p=0.00028 corrected
#                              Mixed Linear Model Regression Results
# ===============================================================================================
# Model:                           MixedLM              Dependent Variable:              beta
# No. Observations:                240                  Method:                          REML
# No. Groups:                      80                   Scale:                           0.0519
# Min. group size:                 3                    Log-Likelihood:                  -60.3881
# Max. group size:                 3                    Converged:                       Yes
# Mean group size:                 3.0
# -----------------------------------------------------------------------------------------------
#                                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                             0.290    0.082  3.530 0.000  0.129  0.450
# C(group, Treatment('DLPFC_20Hz'))[T.DLPFC_cTBS]       0.117    0.114  1.021 0.307 -0.107  0.341
# C(group, Treatment('DLPFC_20Hz'))[T.M1_cTBS]          0.003    0.114  0.027 0.979 -0.221  0.227
# C(group, Treatment('DLPFC_20Hz'))[T.baseline]         0.049    0.102  0.487 0.626 -0.150  0.249
# time                                                 -0.038    0.040 -0.946 0.344 -0.117  0.041
# time:C(group, Treatment('DLPFC_20Hz'))[T.DLPFC_cTBS] -0.232    0.056 -4.136 0.000 -0.342 -0.122
# time:C(group, Treatment('DLPFC_20Hz'))[T.M1_cTBS]    -0.033    0.056 -0.592 0.554 -0.143  0.077
# time:C(group, Treatment('DLPFC_20Hz'))[T.baseline]   -0.094    0.050 -1.893 0.058 -0.192  0.003
# Group Var                                             0.064    0.071
# ===============================================================================================
#
# laPU (dof=232)
# DLPFC_20Hz -> DLPFC_cTBS : **p=0.00195 uncorrected / *p=0.01558 corrected
#                              Mixed Linear Model Regression Results
# ===============================================================================================
# Model:                           MixedLM              Dependent Variable:              beta
# No. Observations:                240                  Method:                          REML
# No. Groups:                      80                   Scale:                           0.0457
# Min. group size:                 3                    Log-Likelihood:                  -50.9347
# Max. group size:                 3                    Converged:                       Yes
# Mean group size:                 3.0
# -----------------------------------------------------------------------------------------------
#                                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                             0.478    0.081  5.886 0.000  0.319  0.637
# C(group, Treatment('DLPFC_20Hz'))[T.DLPFC_cTBS]       0.099    0.113  0.879 0.380 -0.122  0.321
# C(group, Treatment('DLPFC_20Hz'))[T.M1_cTBS]          0.129    0.113  1.137 0.255 -0.093  0.350
# C(group, Treatment('DLPFC_20Hz'))[T.baseline]         0.124    0.100  1.231 0.218 -0.073  0.321
# time                                                 -0.053    0.038 -1.399 0.162 -0.127  0.021
# time:C(group, Treatment('DLPFC_20Hz'))[T.DLPFC_cTBS] -0.163    0.053 -3.098 0.002 -0.266 -0.060
# time:C(group, Treatment('DLPFC_20Hz'))[T.M1_cTBS]    -0.028    0.053 -0.528 0.598 -0.131  0.075
# time:C(group, Treatment('DLPFC_20Hz'))[T.baseline]   -0.080    0.047 -1.711 0.087 -0.172  0.012
# Group Var                                             0.067    0.076
# ===============================================================================================

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Random slope model

# %%
## random slope model (=random intercept and slope model)

print(roi)
df_tmp = df_n50[df_n50['roi']==roi]
# df_tmp = df_tmp.sample(frac=1).reset_index(drop=True)
model = smf.mixedlm(
    "beta ~ time * C(group, Treatment('baseline'))",
    df_tmp,
    groups=df_tmp['subj'],
    re_formula="1 + time"
)
# model = smf.mixedlm("beta ~ time", df_tmp, groups=df_tmp['subj'])
result = model.fit()
print(result.summary())

# %%
g = sns.swarmplot(
    data=df_tmp,
    x='time', y='beta',
    hue='group', hue_order=list_group, palette=palette
)
g.legend(title='')

# *3 means a correction (The degrees of freedom for the ROI is 3)
pval = result.pvalues["time:C(group, Treatment('baseline'))[T.DLPFC_cTBS]"] * 3
g.set_title('%s (%sp=%.4f)'%(roi, convert_pvalue_to_asterisks(pval), pval))

## A group that draws a line with a significant p-value for the slope.
list_line = []
for gg in list_group[1:]:
    ss = "time:C(group, Treatment('baseline'))[T.%s]"%gg
    pval_corrected = result.pvalues[ss] * 3
    # print(pval_corrected)
    if pval_corrected < 0.05:
        list_line.append(ss)
# print(list_line)

x = np.array([0,1,2])
# for ss in list_line:
# y = x * result.params[ss] + result.params.Intercept
# g.plot(
#     x,y,
#     label='slope=%.4f'%result.params.time,
#     linestyle='--', linewidth=2,
#     color=palette[1]
# )

# %%
result.params["time:C(group, Treatment('baseline'))[T.DLPFC_cTBS]"]

# %%
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(12,6))
axs = np.reshape(axs, -1)
palette = sns.color_palette("husl", 3)
x = np.array([0,1,2])

for ii, roi in enumerate(list_roi):
    ax = axs[ii]

    df_tmp = df_n50[df_n50['roi']==roi]
    model = smf.mixedlm("beta ~ time * group", df_tmp, groups=df_tmp['subj'])
    result = model.fit()
    # print(result.summary())

    g = sns.swarmplot(
        data=df_tmp,
        x='time', y='beta',
        hue='group', hue_order=list_group, palette=palette,
        ax=ax
    )
    g.legend().remove()
    g.set_xticks([0, 1, 2])
    g.set_xticklabels(['10 min', '20 min', '30 min'])
    g.set_xlabel('', fontsize=0)

    ## slope: time
    y = x * result.params.time + result.params.Intercept
    ax.plot(
        x,y,
        label='slope=%.4f'%result.params.time,
        linestyle='--', linewidth=2,
        color='b'
    )
    
    # # *8 means a correction (8 ROIs)
    # pval = result.pvalues.time*8
    # g.set_title('%s (%sp=%.4f)'%(roi, convert_pvalue_to_asterisks(pval), pval))

    # ## group
    # y = x * result.params.group + result.params.Intercept
    # ax.plot(
    #     x,y,
    #     label='slope=%.4f'%result.params.group,
    #     linestyle='--', linewidth=2,
    #     color=palette[ii]
    # )
    # # ax.legend().remove()
    # g = sns.swarmplot(
    #     data=df_tmp,
    #     x='time', y='beta', hue='group', palette=palette,
    #     ax=ax
    # )
    # g.set_xticks([0, 1, 2])
    # g.set_xticklabels(['10 min', '20 min', '30 min'])
    # g.set_xlabel('', fontsize=0)
    
    # # *8 means a correction (8 ROIs)
    # pval = result.pvalues.time*8
    # g.set_title('%s (%sp=%.4f)'%(roi, convert_pvalue_to_asterisks(pval), pval))
    
fig.tight_layout()

# %%
for ii, clr in enumerate(palette):
    dx = 0.25*ii
    x, y = 0 + dx, 0
    w, h = 0.045, 0.1
    nax.add_patch(Rectangle((x,y),w , h, facecolor=clr, edgecolor='k'))
    nax.text(x+.085, y, gg, fontsize=13, horizontalalignment='left', verticalalignment='bottom')
    
nax.axis('off')
fig

# %% [markdown]
# ---
