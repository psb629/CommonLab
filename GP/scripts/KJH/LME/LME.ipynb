# %%
# from pymer4.models import Lmer
# from statsmodels.formula.api import ols
# from statsmodels.stats.multitest import multipletests

# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import statsmodels.api as sm
# import statsmodels.formula.api as smf

# %%
rois_left = ['laPU', 'laCA', 'lpPU', 'lpCA']
rois_right = ['raPU', 'raCA', 'rpPU', 'rpCA']
rois_PU = ['laPU','raPU','lpPU','rpPU']
rois_CA = ['laCA','raCA','lpCA','rpCA']
rois_ant = ['laPU', 'laCA', 'raPU', 'raCA']
rois_post = ['lpPU', 'lpCA', 'rpPU', 'rpCA']

# %%
import pandas as pd
import openpyxl

# %%
df = pd.read_excel('./data/Rew#1_Coef_filtered_new_KJH.xlsx')
df_n50 = pd.read_excel('./data/Rew#1_Coef_GPn50_KJH.xlsx')

# %%
# Check the rest of new data (data before GP71) is the same as the old data.
merged_df = pd.merge(df, df_n50, on=['subj', 'group', 'run', 'roi', 'time'], suffixes=('_1', '_n50'))
merged_df['beta_same'] = merged_df['beta_1'] == merged_df['beta_n50']
all(merged_df['beta_same'])
# Out:
# True

# %%
import statsmodels.formula.api as smf

# %%
df_n50['group'] = pd.Categorical(df_n50['group'], categories=['DLPFC_20Hz', 'baseline', 'DLPFC_cTBS'])

# Perform the analysis for each ROI
interaction_results_time_recoded = {}
mixedlm_result = {}

for roi in rois_left + rois_right:
    roi_data = df_n50[df_n50['roi'] == roi].dropna()
    
    # Fit the mixed effects model
    model = smf.mixedlm("beta ~ time * group", roi_data, groups=roi_data['subj'])
    mixedlm_result[roi] = model.fit()
    
    # Get the p-value of the interaction term
    print(roi)
    print(mixedlm_result[roi].df_resid)
    print(mixedlm_result[roi].pvalues['time:group[T.baseline]'])
    print(mixedlm_result[roi].pvalues['time:group[T.baseline]']*8)  # Multiple comparison correction
    print(mixedlm_result[roi].tvalues['time:group[T.baseline]'])
    print(mixedlm_result[roi].pvalues['time:group[T.DLPFC_cTBS]'])
    print(mixedlm_result[roi].pvalues['time:group[T.DLPFC_cTBS]']*8)
    print(mixedlm_result[roi].tvalues['time:group[T.DLPFC_cTBS]'])
#     print(result.df_n50_model)
    print(mixedlm_result[roi].summary())
    print('-----------------')
#     interaction_results_time_recoded[roi] = {f"time:group_recoded[T.{group}]": p_val for group, p_val in mixedlm_result.pvalues.items() if "group_recoded" in group}

#     print(mixedlm_result.summary())
# Out:
# laPU
# 183
# 0.09893204506665455
# 0.7914563605332364
# -1.6500532512939659
# 0.0028134633296938703
# 0.022507706637550962
# -2.9874162885954396
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      189         Method:                 REML
# No. Groups:            63          Scale:                  0.0492
# Min. group size:       3           Log-Likelihood:         -44.9661
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.478    0.083  5.783 0.000  0.316  0.639
# group[T.baseline]         0.124    0.102  1.210 0.226 -0.077  0.324
# group[T.DLPFC_cTBS]       0.099    0.115  0.863 0.388 -0.126  0.325
# time                     -0.053    0.039 -1.349 0.177 -0.130  0.024
# time:group[T.baseline]   -0.080    0.049 -1.650 0.099 -0.175  0.015
# time:group[T.DLPFC_cTBS] -0.163    0.055 -2.987 0.003 -0.270 -0.056
# Group Var                 0.068    0.085
# ===================================================================
#
# -----------------
# laCA
# 183
# 0.41735755661331164
# 3.338860452906493
# -0.811014129509829
# 8.297442813620145e-05
# 0.0006637954250896116
# -3.935642454686125
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      189         Method:                 REML
# No. Groups:            63          Scale:                  0.0502
# Min. group size:       3           Log-Likelihood:         -43.4834
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.393    0.080  4.919 0.000  0.236  0.550
# group[T.baseline]         0.033    0.099  0.331 0.741 -0.161  0.227
# group[T.DLPFC_cTBS]       0.151    0.111  1.360 0.174 -0.067  0.370
# time                     -0.047    0.040 -1.189 0.235 -0.125  0.031
# time:group[T.baseline]   -0.040    0.049 -0.811 0.417 -0.136  0.056
# time:group[T.DLPFC_cTBS] -0.217    0.055 -3.936 0.000 -0.325 -0.109
# Group Var                 0.060    0.077
# ===================================================================
#
# -----------------
# lpPU
# 183
# 0.0981783243712306
# 0.7854265949698448
# -1.6537499730919623
# 0.1199972313721781
# 0.9599778509774248
# -1.5547852155837443
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM      Dependent Variable:      beta
# No. Observations:      189          Method:                  REML
# No. Groups:            63           Scale:                   0.0332
# Min. group size:       3            Log-Likelihood:          0.0890
# Max. group size:       3            Converged:               Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.239    0.061  3.938 0.000  0.120  0.357
# group[T.baseline]         0.040    0.075  0.533 0.594 -0.107  0.187
# group[T.DLPFC_cTBS]       0.033    0.084  0.389 0.697 -0.133  0.198
# time                     -0.040    0.032 -1.226 0.220 -0.103  0.024
# time:group[T.baseline]   -0.066    0.040 -1.654 0.098 -0.144  0.012
# time:group[T.DLPFC_cTBS] -0.070    0.045 -1.555 0.120 -0.158  0.018
# Group Var                 0.031    0.052
# ===================================================================
#
# -----------------
# lpCA
# 183
# 0.04829923437245544
# 0.3863938749796435
# -1.9747261439359818
# 0.0013781596131360223
# 0.011025276905088179
# -3.199186547472223
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      189         Method:                 REML
# No. Groups:            63          Scale:                  0.0630
# Min. group size:       3           Log-Likelihood:         -64.6326
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.302    0.090  3.358 0.001  0.126  0.479
# group[T.baseline]         0.066    0.111  0.590 0.555 -0.153  0.284
# group[T.DLPFC_cTBS]       0.102    0.125  0.817 0.414 -0.143  0.348
# time                     -0.051    0.044 -1.150 0.250 -0.138  0.036
# time:group[T.baseline]   -0.108    0.055 -1.975 0.048 -0.216 -0.001
# time:group[T.DLPFC_cTBS] -0.198    0.062 -3.199 0.001 -0.319 -0.077
# Group Var                 0.077    0.087
# ===================================================================
#
# -----------------
# raPU
# 183
# 0.17111006425357767
# 1.3688805140286213
# -1.3686456589344365
# 0.0006321786037652705
# 0.005057428830122164
# -3.4174191821184383
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      189         Method:                 REML
# No. Groups:            63          Scale:                  0.0384
# Min. group size:       3           Log-Likelihood:         -22.8208
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.472    0.073  6.417 0.000  0.328  0.616
# group[T.baseline]         0.125    0.091  1.370 0.171 -0.054  0.303
# group[T.DLPFC_cTBS]       0.144    0.102  1.403 0.161 -0.057  0.344
# time                     -0.034    0.035 -0.996 0.319 -0.102  0.033
# time:group[T.baseline]   -0.059    0.043 -1.369 0.171 -0.143  0.025
# time:group[T.DLPFC_cTBS] -0.165    0.048 -3.417 0.001 -0.259 -0.070
# Group Var                 0.054    0.076
# ===================================================================
#
# -----------------
# raCA
# 183
# 0.22070481077515458
# 1.7656384862012366
# -1.2246561275021894
# 0.0005321578772361499
# 0.0042572630178891995
# -3.4640245825782903
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      189         Method:                 REML
# No. Groups:            63          Scale:                  0.0539
# Min. group size:       3           Log-Likelihood:         -52.3657
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.397    0.085  4.650 0.000  0.230  0.565
# group[T.baseline]         0.081    0.106  0.764 0.445 -0.126  0.288
# group[T.DLPFC_cTBS]       0.098    0.119  0.824 0.410 -0.135  0.331
# time                     -0.046    0.041 -1.116 0.264 -0.126  0.035
# time:group[T.baseline]   -0.062    0.051 -1.225 0.221 -0.162  0.037
# time:group[T.DLPFC_cTBS] -0.198    0.057 -3.464 0.001 -0.310 -0.086
# Group Var                 0.072    0.086
# ===================================================================
#
# -----------------
# rpPU
# 183
# 0.04218253008181514
# 0.3374602406545211
# -2.0317148658206907
# 0.07521584107735527
# 0.6017267286188421
# -1.7791459251106252
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM      Dependent Variable:      beta
# No. Observations:      189          Method:                  REML
# No. Groups:            63           Scale:                   0.0293
# Min. group size:       3            Log-Likelihood:          7.5440
# Max. group size:       3            Converged:               Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.269    0.060  4.490 0.000  0.151  0.386
# group[T.baseline]         0.056    0.074  0.759 0.448 -0.089  0.201
# group[T.DLPFC_cTBS]       0.027    0.083  0.324 0.746 -0.136  0.190
# time                     -0.015    0.030 -0.512 0.608 -0.075  0.044
# time:group[T.baseline]   -0.076    0.037 -2.032 0.042 -0.149 -0.003
# time:group[T.DLPFC_cTBS] -0.075    0.042 -1.779 0.075 -0.158  0.008
# Group Var                 0.033    0.055
# ===================================================================
#
# -----------------
# rpCA
# 183
# 0.0714262351363165
# 0.571409881090532
# -1.8027579602259907
# 8.150254132735694e-05
# 0.0006520203306188555
# -3.9399383789328355
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      189         Method:                 REML
# No. Groups:            63          Scale:                  0.0572
# Min. group size:       3           Log-Likelihood:         -53.8154
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.290    0.084  3.461 0.001  0.126  0.454
# group[T.baseline]         0.049    0.104  0.477 0.633 -0.154  0.253
# group[T.DLPFC_cTBS]       0.117    0.117  1.001 0.317 -0.112  0.345
# time                     -0.038    0.042 -0.901 0.368 -0.121  0.045
# time:group[T.baseline]   -0.094    0.052 -1.803 0.071 -0.197  0.008
# time:group[T.DLPFC_cTBS] -0.232    0.059 -3.940 0.000 -0.347 -0.117
# Group Var                 0.064    0.078
# ===================================================================
#
# -----------------

# %% [markdown]
# -----------------------------------------------------

# %%
df['group'] = pd.Categorical(df['group'], categories=['DLPFC_cTBS', 'baseline', 'M1_cTBS'])

# Perform the analysis for each ROI
interaction_results_time_recoded = {}
mixedlm_result = {}

for roi in rois_left + rois_right:
    roi_data = df[df['roi'] == roi].dropna()
    
    # Fit the mixed effects model
    model = smf.mixedlm("beta ~ time * group", roi_data, groups=roi_data['subj'])
#     model = Lmer('beta ~ time * group + (1|subj)',data =roi_data )
#     model = smf.mixedlm("beta ~ time * group_recoded", roi_data, groups=roi_data['subj'], re_formula="~time")
    mixedlm_result[roi] = model.fit()
    
    # Get the p-value of the interaction term
    print(roi)
    print(mixedlm_result[roi].df_resid)
    print(mixedlm_result[roi].pvalues['time:group[T.baseline]'])
    print(mixedlm_result[roi].pvalues['time:group[T.baseline]']*8)
    print(mixedlm_result[roi].tvalues['time:group[T.baseline]'])
    print(mixedlm_result[roi].pvalues['time:group[T.M1_cTBS]']*8)
    print(mixedlm_result[roi].tvalues['time:group[T.M1_cTBS]'])
#     print(result.df_model)
    print(mixedlm_result[roi].summary())
    print('-----------------')
#     interaction_results_time_recoded[roi] = {f"time:group_recoded[T.{group}]": p_val for group, p_val in mixedlm_result.pvalues.items() if "group_recoded" in group}

#     print(mixedlm_result.summary())
# Out:
# laPU
# 186
# 0.07983801566227176
# 0.6387041252981741
# 1.7516267157568373
# 0.09218215813727862
# 2.5264319853504613
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0488
# Min. group size:       3          Log-Likelihood:        -44.9340
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.577    0.080  7.224 0.000  0.420  0.734
# group[T.baseline]       0.024    0.100  0.244 0.807 -0.172  0.220
# group[T.M1_cTBS]        0.029    0.113  0.259 0.796 -0.192  0.251
# time                   -0.216    0.038 -5.703 0.000 -0.290 -0.142
# time:group[T.baseline]  0.083    0.047  1.752 0.080 -0.010  0.176
# time:group[T.M1_cTBS]   0.135    0.054  2.526 0.012  0.030  0.240
# Group Var               0.068    0.084
# =================================================================
#
# -----------------
# laCA
# 186
# 0.0004584251214470607
# 0.0036674009715764854
# 3.5039420404478245
# 0.007326246612828254
# 3.315198461542528
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0557
# Min. group size:       3          Log-Likelihood:        -50.0509
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.545    0.078  6.969 0.000  0.391  0.698
# group[T.baseline]      -0.119    0.098 -1.213 0.225 -0.310  0.073
# group[T.M1_cTBS]       -0.073    0.110 -0.657 0.511 -0.289  0.144
# time                   -0.264    0.040 -6.533 0.000 -0.344 -0.185
# time:group[T.baseline]  0.177    0.051  3.504 0.000  0.078  0.277
# time:group[T.M1_cTBS]   0.190    0.057  3.315 0.001  0.078  0.302
# Group Var               0.057    0.071
# =================================================================
#
# -----------------
# lpPU
# 186
# 0.9258452442102142
# 7.4067619536817135
# 0.09307340654810868
# 0.9090956977743039
# 1.5820552323963026
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                MixedLM     Dependent Variable:     beta
# No. Observations:     192         Method:                 REML
# No. Groups:           64          Scale:                  0.0364
# Min. group size:      3           Log-Likelihood:         -6.1014
# Max. group size:      3           Converged:              Yes
# Mean group size:      3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.272    0.060  4.531 0.000  0.154  0.389
# group[T.baseline]       0.007    0.075  0.096 0.924 -0.140  0.154
# group[T.M1_cTBS]       -0.035    0.085 -0.414 0.679 -0.201  0.131
# time                   -0.109    0.033 -3.338 0.001 -0.173 -0.045
# time:group[T.baseline]  0.004    0.041  0.093 0.926 -0.077  0.084
# time:group[T.M1_cTBS]   0.073    0.046  1.582 0.114 -0.017  0.164
# Group Var               0.031    0.050
# =================================================================
#
# -----------------
# lpCA
# 186
# 0.09570183361144244
# 0.7656146688915395
# 1.6660581466559965
# 0.10149657225441894
# 2.492434536820583
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0623
# Min. group size:       3          Log-Likelihood:        -64.2842
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.405    0.087  4.676 0.000  0.235  0.574
# group[T.baseline]      -0.037    0.108 -0.340 0.734 -0.249  0.176
# group[T.M1_cTBS]       -0.054    0.122 -0.442 0.659 -0.294  0.186
# time                   -0.249    0.043 -5.812 0.000 -0.333 -0.165
# time:group[T.baseline]  0.089    0.054  1.666 0.096 -0.016  0.194
# time:group[T.M1_cTBS]   0.151    0.061  2.492 0.013  0.032  0.270
# Group Var               0.075    0.085
# =================================================================
#
# -----------------
# raPU
# 186
# 0.013394664585076224
# 0.1071573166806098
# 2.4731000288803164
# 0.154049281271532
# 2.3405344818782865
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0400
# Min. group size:       3          Log-Likelihood:        -24.5262
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.615    0.071  8.716 0.000  0.477  0.754
# group[T.baseline]      -0.019    0.088 -0.215 0.830 -0.192  0.154
# group[T.M1_cTBS]       -0.032    0.100 -0.323 0.747 -0.228  0.163
# time                   -0.199    0.034 -5.812 0.000 -0.267 -0.132
# time:group[T.baseline]  0.106    0.043  2.473 0.013  0.022  0.190
# time:group[T.M1_cTBS]   0.114    0.049  2.341 0.019  0.018  0.209
# Group Var               0.051    0.071
# =================================================================
#
# -----------------
# raCA
# 186
# 0.006799492637929615
# 0.05439594110343692
# 2.706508086541793
# 0.03466433291037979
# 2.8528401167625375
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0546
# Min. group size:       3          Log-Likelihood:        -48.0596
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.495    0.077  6.417 0.000  0.344  0.647
# group[T.baseline]      -0.017    0.097 -0.179 0.858 -0.207  0.172
# group[T.M1_cTBS]       -0.009    0.109 -0.080 0.936 -0.223  0.205
# time                   -0.244    0.040 -6.082 0.000 -0.322 -0.165
# time:group[T.baseline]  0.136    0.050  2.707 0.007  0.037  0.234
# time:group[T.M1_cTBS]   0.162    0.057  2.853 0.004  0.051  0.273
# Group Var               0.056    0.070
# =================================================================
#
# -----------------
# rpPU
# 186
# 0.9762118638767011
# 7.809694911013609
# -0.02981842549945819
# 2.1182665705454564
# 1.1151565978857454
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      192         Method:                 REML
# No. Groups:            64          Scale:                  0.0306
# Min. group size:       3           Log-Likelihood:         6.1553
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.296    0.058  5.134 0.000  0.183  0.408
# group[T.baseline]       0.029    0.072  0.405 0.686 -0.112  0.170
# group[T.M1_cTBS]       -0.012    0.081 -0.149 0.881 -0.172  0.147
# time                   -0.090    0.030 -3.016 0.003 -0.149 -0.032
# time:group[T.baseline] -0.001    0.038 -0.030 0.976 -0.075  0.072
# time:group[T.M1_cTBS]   0.047    0.042  1.115 0.265 -0.036  0.130
# Group Var               0.031    0.052
# =================================================================
#
# -----------------
# rpCA
# 186
# 0.005582020108534501
# 0.04465616086827601
# 2.771374409227573
# 0.003169087104723449
# 3.5426447928782894
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0536
# Min. group size:       3          Log-Likelihood:        -49.5591
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.406    0.080  5.104 0.000  0.250  0.562
# group[T.baseline]      -0.067    0.100 -0.675 0.500 -0.262  0.128
# group[T.M1_cTBS]       -0.114    0.113 -1.009 0.313 -0.334  0.107
# time                   -0.270    0.040 -6.806 0.000 -0.348 -0.192
# time:group[T.baseline]  0.138    0.050  2.771 0.006  0.040  0.235
# time:group[T.M1_cTBS]   0.199    0.056  3.543 0.000  0.089  0.309
# Group Var               0.063    0.077
# =================================================================
#
# -----------------

# %%
from scipy.stats import f_oneway

# %%
for roi in rois_left + rois_right:
    print(roi)
    df_first_run = df[(df['run'] == 'r01') & (df['roi'] == roi)]
    print(df_first_run)
    
    # Group the data by species
    base = df[df['group'] == 'baseline']['beta']
    m1 = df[df['group'] == 'M1_cTBS']['beta']
    dlpfc = df[df['group'] == 'DLPFC_cTBS']['beta']

    # Perform one-way ANOVA
    f_stat, p_value = f_oneway(base, m1, dlpfc)
    print(f"F-statistic: {f_stat}, P-value: {p_value}")
# Out:
# laPU
#      subj       group  run   roi      beta  time
# 1    GA01    baseline  r01  laPU  0.599993     0
# 9    GA02    baseline  r01  laPU  0.833855     0
# 17   GA05    baseline  r01  laPU  0.946376     0
# 25   GA07    baseline  r01  laPU  0.840314     0
# 33   GA08    baseline  r01  laPU  0.041963     0
# ..    ...         ...  ...   ...       ...   ...
# 473  GP62  DLPFC_cTBS  r01  laPU  0.420961     0
# 481  GP63     M1_cTBS  r01  laPU  0.312670     0
# 489  GP65     M1_cTBS  r01  laPU  0.211766     0
# 497  GP66  DLPFC_cTBS  r01  laPU  0.960290     0
# 505  GP67  DLPFC_cTBS  r01  laPU  0.621317     0
#
# [64 rows x 6 columns]
# F-statistic: 8.15827038020948, P-value: 0.00029897231261175934
# laCA
#      subj       group  run   roi      beta  time
# 4    GA01    baseline  r01  laCA  0.538827     0
# 12   GA02    baseline  r01  laCA  0.579527     0
# 20   GA05    baseline  r01  laCA  0.964707     0
# 28   GA07    baseline  r01  laCA  0.663282     0
# 36   GA08    baseline  r01  laCA -0.190635     0
# ..    ...         ...  ...   ...       ...   ...
# 476  GP62  DLPFC_cTBS  r01  laCA -0.061746     0
# 484  GP63     M1_cTBS  r01  laCA  0.207415     0
# 492  GP65     M1_cTBS  r01  laCA  0.205530     0
# 500  GP66  DLPFC_cTBS  r01  laCA  1.161963     0
# 508  GP67  DLPFC_cTBS  r01  laCA  1.107865     0
#
# [64 rows x 6 columns]
# F-statistic: 8.15827038020948, P-value: 0.00029897231261175934
# lpPU
#      subj       group  run   roi      beta  time
# 2    GA01    baseline  r01  lpPU  0.151185     0
# 10   GA02    baseline  r01  lpPU  0.430958     0
# 18   GA05    baseline  r01  lpPU  0.779839     0
# 26   GA07    baseline  r01  lpPU  0.164638     0
# 34   GA08    baseline  r01  lpPU -0.203428     0
# ..    ...         ...  ...   ...       ...   ...
# 474  GP62  DLPFC_cTBS  r01  lpPU -0.199731     0
# 482  GP63     M1_cTBS  r01  lpPU -0.105692     0
# 490  GP65     M1_cTBS  r01  lpPU  0.258486     0
# 498  GP66  DLPFC_cTBS  r01  lpPU  0.476613     0
# 506  GP67  DLPFC_cTBS  r01  lpPU  0.039715     0
#
# [64 rows x 6 columns]
# F-statistic: 8.15827038020948, P-value: 0.00029897231261175934
# lpCA
#      subj       group  run   roi      beta  time
# 5    GA01    baseline  r01  lpCA  0.573242     0
# 13   GA02    baseline  r01  lpCA  0.604885     0
# 21   GA05    baseline  r01  lpCA  1.010146     0
# 29   GA07    baseline  r01  lpCA  0.361954     0
# 37   GA08    baseline  r01  lpCA -0.376969     0
# ..    ...         ...  ...   ...       ...   ...
# 477  GP62  DLPFC_cTBS  r01  lpCA -0.342444     0
# 485  GP63     M1_cTBS  r01  lpCA  0.048269     0
# 493  GP65     M1_cTBS  r01  lpCA  0.387777     0
# 501  GP66  DLPFC_cTBS  r01  lpCA  0.597381     0
# 509  GP67  DLPFC_cTBS  r01  lpCA  0.942126     0
#
# [64 rows x 6 columns]
# F-statistic: 8.15827038020948, P-value: 0.00029897231261175934
# raPU
#      subj       group  run   roi      beta  time
# 0    GA01    baseline  r01  raPU  0.518611     0
# 8    GA02    baseline  r01  raPU  0.575595     0
# 16   GA05    baseline  r01  raPU  1.247181     0
# 24   GA07    baseline  r01  raPU  0.918631     0
# 32   GA08    baseline  r01  raPU  0.321577     0
# ..    ...         ...  ...   ...       ...   ...
# 472  GP62  DLPFC_cTBS  r01  raPU  0.364803     0
# 480  GP63     M1_cTBS  r01  raPU  0.396775     0
# 488  GP65     M1_cTBS  r01  raPU  0.329915     0
# 496  GP66  DLPFC_cTBS  r01  raPU  1.141537     0
# 504  GP67  DLPFC_cTBS  r01  raPU  0.959659     0
#
# [64 rows x 6 columns]
# F-statistic: 8.15827038020948, P-value: 0.00029897231261175934
# raCA
#      subj       group  run   roi      beta  time
# 6    GA01    baseline  r01  raCA  0.612334     0
# 14   GA02    baseline  r01  raCA  0.536134     0
# 22   GA05    baseline  r01  raCA  1.138966     0
# 30   GA07    baseline  r01  raCA  0.735999     0
# 38   GA08    baseline  r01  raCA  0.060519     0
# ..    ...         ...  ...   ...       ...   ...
# 478  GP62  DLPFC_cTBS  r01  raCA  0.126403     0
# 486  GP63     M1_cTBS  r01  raCA  0.312368     0
# 494  GP65     M1_cTBS  r01  raCA  0.379600     0
# 502  GP66  DLPFC_cTBS  r01  raCA  0.952247     0
# 510  GP67  DLPFC_cTBS  r01  raCA  0.700499     0
#
# [64 rows x 6 columns]
# F-statistic: 8.15827038020948, P-value: 0.00029897231261175934
# rpPU
#      subj       group  run   roi      beta  time
# 3    GA01    baseline  r01  rpPU  0.272298     0
# 11   GA02    baseline  r01  rpPU  0.550425     0
# 19   GA05    baseline  r01  rpPU  0.860117     0
# 27   GA07    baseline  r01  rpPU  0.222494     0
# 35   GA08    baseline  r01  rpPU  0.007133     0
# ..    ...         ...  ...   ...       ...   ...
# 475  GP62  DLPFC_cTBS  r01  rpPU -0.064210     0
# 483  GP63     M1_cTBS  r01  rpPU -0.009070     0
# 491  GP65     M1_cTBS  r01  rpPU  0.184314     0
# 499  GP66  DLPFC_cTBS  r01  rpPU  0.590562     0
# 507  GP67  DLPFC_cTBS  r01  rpPU  0.094211     0
#
# [64 rows x 6 columns]
# F-statistic: 8.15827038020948, P-value: 0.00029897231261175934
# rpCA
#      subj       group  run   roi      beta  time
# 7    GA01    baseline  r01  rpCA  0.499191     0
# 15   GA02    baseline  r01  rpCA  0.558398     0
# 23   GA05    baseline  r01  rpCA  1.032832     0
# 31   GA07    baseline  r01  rpCA  0.335405     0
# 39   GA08    baseline  r01  rpCA -0.372835     0
# ..    ...         ...  ...   ...       ...   ...
# 479  GP62  DLPFC_cTBS  r01  rpCA -0.235957     0
# 487  GP63     M1_cTBS  r01  rpCA -0.025048     0
# 495  GP65     M1_cTBS  r01  rpCA  0.328753     0
# 503  GP66  DLPFC_cTBS  r01  rpCA  0.778816     0
# 511  GP67  DLPFC_cTBS  r01  rpCA  0.910500     0
#
# [64 rows x 6 columns]
# F-statistic: 8.15827038020948, P-value: 0.00029897231261175934

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
# Subset the data to include only the first run
for roi in rois_left + rois_right:
    df_first_run = df[(df['run'] == 'r01') & (df['roi'] == roi)]

    # Fit the model
    model = ols('beta ~ group', data=df_first_run).fit()

    # Perform the ANOVA
    anova_table = sm.stats.anova_lm(model, typ=2)

    print(roi)
    print(anova_table)
    print('--------------')
# Out:
# laPU
#             sum_sq    df         F    PR(>F)
# group     0.007092   2.0  0.044343  0.956657
# Residual  4.878059  61.0       NaN       NaN
# --------------
# laCA
#             sum_sq    df         F    PR(>F)
# group     0.255806   2.0  1.216573  0.303329
# Residual  6.413166  61.0       NaN       NaN
# --------------
# lpPU
#             sum_sq    df         F    PR(>F)
# group     0.034784   2.0  0.323626  0.724755
# Residual  3.278172  61.0       NaN       NaN
# --------------
# lpCA
#             sum_sq    df         F    PR(>F)
# group     0.070531   2.0  0.339899  0.713182
# Residual  6.328969  61.0       NaN       NaN
# --------------
# raPU
#             sum_sq    df         F    PR(>F)
# group     0.045067   2.0  0.334716  0.716847
# Residual  4.106603  61.0       NaN       NaN
# --------------
# raCA
#             sum_sq    df         F    PR(>F)
# group     0.026174   2.0  0.147608  0.863077
# Residual  5.408274  61.0       NaN       NaN
# --------------
# rpPU
#             sum_sq    df        F    PR(>F)
# group     0.068982   2.0  0.72749  0.487264
# Residual  2.892069  61.0      NaN       NaN
# --------------
# rpCA
#             sum_sq    df         F    PR(>F)
# group     0.164995   2.0  0.782798  0.461663
# Residual  6.428663  61.0       NaN       NaN
# --------------

# %%
df_baseline = df[df['group']=='baseline']
unique_rois = df['roi'].unique()

for roi in unique_rois:
    roi_data = df_baseline[df_baseline['roi']==roi]
    model = smf.mixedlm("beta ~ time", roi_data, groups=roi_data["subj"])
    result = model.fit()
    
    print(f"ROI: {roi}")
    print(result.summary())
    print("\n")
# Out:
# ROI: raPU
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: beta
# No. Observations: 90      Method:             REML
# No. Groups:       30      Scale:              0.0454
# Min. group size:  3       Log-Likelihood:     -15.6891
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.596    0.056 10.619 0.000  0.486  0.706
# time        -0.093    0.028 -3.388 0.001 -0.147 -0.039
# Group Var    0.057    0.108
# ======================================================
#
#
#
# ROI: laPU
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: beta
# No. Observations: 90      Method:             REML
# No. Groups:       30      Scale:              0.0602
# Min. group size:  3       Log-Likelihood:     -29.8122
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.601    0.068  8.893 0.000  0.469  0.734
# time        -0.133    0.032 -4.198 0.000 -0.195 -0.071
# Group Var    0.087    0.140
# ======================================================
#
#
#
# ROI: lpPU
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: beta
# No. Observations: 90      Method:             REML
# No. Groups:       30      Scale:              0.0473
# Min. group size:  3       Log-Likelihood:     -10.9463
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.279    0.049  5.720 0.000  0.183  0.374
# time        -0.105    0.028 -3.754 0.000 -0.161 -0.050
# Group Var    0.032    0.070
# ======================================================
#
#
#
# ROI: rpPU
#         Mixed Linear Model Regression Results
# =====================================================
# Model:            MixedLM Dependent Variable: beta
# No. Observations: 90      Method:             REML
# No. Groups:       30      Scale:              0.0399
# Min. group size:  3       Log-Likelihood:     -6.4742
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# -----------------------------------------------------
#            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------
# Intercept   0.325    0.048  6.754 0.000  0.231  0.419
# time       -0.092    0.026 -3.549 0.000 -0.142 -0.041
# Group Var   0.036    0.079
# =====================================================
#
#
#
# ROI: laCA
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: beta
# No. Observations: 90      Method:             REML
# No. Groups:       30      Scale:              0.0549
# Min. group size:  3       Log-Likelihood:     -22.6488
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.426    0.060  7.155 0.000  0.309  0.542
# time        -0.087    0.030 -2.872 0.004 -0.146 -0.028
# Group Var    0.060    0.108
# ======================================================
#
#
#
# ROI: lpCA
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: beta
# No. Observations: 90      Method:             REML
# No. Groups:       30      Scale:              0.0853
# Min. group size:  3       Log-Likelihood:     -40.9786
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.368    0.072  5.094 0.000  0.226  0.509
# time        -0.160    0.038 -4.230 0.000 -0.233 -0.086
# Group Var    0.085    0.125
# ======================================================
#
#
#
# ROI: raCA
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: beta
# No. Observations: 90      Method:             REML
# No. Groups:       30      Scale:              0.0652
# Min. group size:  3       Log-Likelihood:     -28.6696
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.478    0.062  7.662 0.000  0.356  0.600
# time        -0.108    0.033 -3.276 0.001 -0.173 -0.043
# Group Var    0.062    0.106
# ======================================================
#
#
#
# ROI: rpCA
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: beta
# No. Observations: 90      Method:             REML
# No. Groups:       30      Scale:              0.0728
# Min. group size:  3       Log-Likelihood:     -31.8729
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.339    0.063  5.354 0.000  0.215  0.463
# time        -0.132    0.035 -3.801 0.000 -0.201 -0.064
# Group Var    0.060    0.100
# ======================================================

# %%
# Create a new column 'region' in the data for anterior vs posterior comparision
df["region"] = "anterior"
df.loc[df['roi'].isin(rois_post), "region"] = "posterior"

## Make a label for right and left ROIs
df["LR"] = "left"
df.loc[df['roi'].isin(rois_right), "LR"] = "right"

# Define PC for comparing putamen versus caudate nucleus
df["PC"] = "PU"
df.loc[df['roi'].isin(rois_CA), "PC"] = "CA"

# Convert 'region' to categorical
df["region"] = pd.Categorical(df["region"])

df
# Out:
#       subj       group  run   roi      beta  time     region     LR  PC
# 0     GA01    baseline  r01  raPU  0.518611     0   anterior  right  PU
# 1     GA01    baseline  r01  laPU  0.599993     0   anterior   left  PU
# 2     GA01    baseline  r01  lpPU  0.151185     0  posterior   left  PU
# 3     GA01    baseline  r01  rpPU  0.272298     0  posterior  right  PU
# 4     GA01    baseline  r01  laCA  0.538827     0   anterior   left  CA
# ...    ...         ...  ...   ...       ...   ...        ...    ...  ..
# 1531  GP67  DLPFC_cTBS  r03  rpPU  0.018424     2  posterior  right  PU
# 1532  GP67  DLPFC_cTBS  r03  laCA  0.016947     2   anterior   left  CA
# 1533  GP67  DLPFC_cTBS  r03  lpCA -0.135706     2  posterior   left  CA
# 1534  GP67  DLPFC_cTBS  r03  raCA -0.021755     2   anterior  right  CA
# 1535  GP67  DLPFC_cTBS  r03  rpCA -0.045155     2  posterior  right  CA
#
# [1536 rows x 9 columns]

# %%
df['group'] = pd.Categorical(df['group'], categories=['DLPFC_cTBS', 'baseline', 'M1_cTBS'])

# Perform the analysis for each ROI
interaction_results_time_recoded = {}
mixedlm_result = {}

for roi in rois_left + rois_right:
    roi_data = df[df['roi'] == roi].dropna()
    
    # Fit the mixed effects model
    model = smf.mixedlm("beta ~ time * group", roi_data, groups=roi_data['subj'])
#     model = Lmer('beta ~ time * group + (1|subj)',data =roi_data )
#     model = smf.mixedlm("beta ~ time * group_recoded", roi_data, groups=roi_data['subj'], re_formula="~time")
    mixedlm_result[roi] = model.fit()
    
    # Get the p-value of the interaction term
    print(roi)
    print(mixedlm_result[roi].df_resid)
    print(mixedlm_result[roi].pvalues['time:group[T.baseline]'])
    print(mixedlm_result[roi].pvalues['time:group[T.baseline]']*8)
    print(mixedlm_result[roi].tvalues['time:group[T.baseline]'])
    print(mixedlm_result[roi].pvalues['time:group[T.M1_cTBS]']*8)
    print(mixedlm_result[roi].tvalues['time:group[T.M1_cTBS]'])
#     print(result.df_model)
    print(mixedlm_result[roi].summary())
    print('-----------------')
#     interaction_results_time_recoded[roi] = {f"time:group_recoded[T.{group}]": p_val for group, p_val in mixedlm_result.pvalues.items() if "group_recoded" in group}

#     print(mixedlm_result.summary())
# Out:
# laPU
# 186
# 0.07983801566227176
# 0.6387041252981741
# 1.7516267157568373
# 0.09218215813727862
# 2.5264319853504613
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0488
# Min. group size:       3          Log-Likelihood:        -44.9340
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.577    0.080  7.224 0.000  0.420  0.734
# group[T.baseline]       0.024    0.100  0.244 0.807 -0.172  0.220
# group[T.M1_cTBS]        0.029    0.113  0.259 0.796 -0.192  0.251
# time                   -0.216    0.038 -5.703 0.000 -0.290 -0.142
# time:group[T.baseline]  0.083    0.047  1.752 0.080 -0.010  0.176
# time:group[T.M1_cTBS]   0.135    0.054  2.526 0.012  0.030  0.240
# Group Var               0.068    0.084
# =================================================================
#
# -----------------
# laCA
# 186
# 0.0004584251214470607
# 0.0036674009715764854
# 3.5039420404478245
# 0.007326246612828254
# 3.315198461542528
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0557
# Min. group size:       3          Log-Likelihood:        -50.0509
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.545    0.078  6.969 0.000  0.391  0.698
# group[T.baseline]      -0.119    0.098 -1.213 0.225 -0.310  0.073
# group[T.M1_cTBS]       -0.073    0.110 -0.657 0.511 -0.289  0.144
# time                   -0.264    0.040 -6.533 0.000 -0.344 -0.185
# time:group[T.baseline]  0.177    0.051  3.504 0.000  0.078  0.277
# time:group[T.M1_cTBS]   0.190    0.057  3.315 0.001  0.078  0.302
# Group Var               0.057    0.071
# =================================================================
#
# -----------------
# lpPU
# 186
# 0.9258452442102142
# 7.4067619536817135
# 0.09307340654810868
# 0.9090956977743039
# 1.5820552323963026
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                MixedLM     Dependent Variable:     beta
# No. Observations:     192         Method:                 REML
# No. Groups:           64          Scale:                  0.0364
# Min. group size:      3           Log-Likelihood:         -6.1014
# Max. group size:      3           Converged:              Yes
# Mean group size:      3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.272    0.060  4.531 0.000  0.154  0.389
# group[T.baseline]       0.007    0.075  0.096 0.924 -0.140  0.154
# group[T.M1_cTBS]       -0.035    0.085 -0.414 0.679 -0.201  0.131
# time                   -0.109    0.033 -3.338 0.001 -0.173 -0.045
# time:group[T.baseline]  0.004    0.041  0.093 0.926 -0.077  0.084
# time:group[T.M1_cTBS]   0.073    0.046  1.582 0.114 -0.017  0.164
# Group Var               0.031    0.050
# =================================================================
#
# -----------------
# lpCA
# 186
# 0.09570183361144244
# 0.7656146688915395
# 1.6660581466559965
# 0.10149657225441894
# 2.492434536820583
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0623
# Min. group size:       3          Log-Likelihood:        -64.2842
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.405    0.087  4.676 0.000  0.235  0.574
# group[T.baseline]      -0.037    0.108 -0.340 0.734 -0.249  0.176
# group[T.M1_cTBS]       -0.054    0.122 -0.442 0.659 -0.294  0.186
# time                   -0.249    0.043 -5.812 0.000 -0.333 -0.165
# time:group[T.baseline]  0.089    0.054  1.666 0.096 -0.016  0.194
# time:group[T.M1_cTBS]   0.151    0.061  2.492 0.013  0.032  0.270
# Group Var               0.075    0.085
# =================================================================
#
# -----------------
# raPU
# 186
# 0.013394664585076224
# 0.1071573166806098
# 2.4731000288803164
# 0.154049281271532
# 2.3405344818782865
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0400
# Min. group size:       3          Log-Likelihood:        -24.5262
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.615    0.071  8.716 0.000  0.477  0.754
# group[T.baseline]      -0.019    0.088 -0.215 0.830 -0.192  0.154
# group[T.M1_cTBS]       -0.032    0.100 -0.323 0.747 -0.228  0.163
# time                   -0.199    0.034 -5.812 0.000 -0.267 -0.132
# time:group[T.baseline]  0.106    0.043  2.473 0.013  0.022  0.190
# time:group[T.M1_cTBS]   0.114    0.049  2.341 0.019  0.018  0.209
# Group Var               0.051    0.071
# =================================================================
#
# -----------------
# raCA
# 186
# 0.006799492637929615
# 0.05439594110343692
# 2.706508086541793
# 0.03466433291037979
# 2.8528401167625375
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0546
# Min. group size:       3          Log-Likelihood:        -48.0596
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.495    0.077  6.417 0.000  0.344  0.647
# group[T.baseline]      -0.017    0.097 -0.179 0.858 -0.207  0.172
# group[T.M1_cTBS]       -0.009    0.109 -0.080 0.936 -0.223  0.205
# time                   -0.244    0.040 -6.082 0.000 -0.322 -0.165
# time:group[T.baseline]  0.136    0.050  2.707 0.007  0.037  0.234
# time:group[T.M1_cTBS]   0.162    0.057  2.853 0.004  0.051  0.273
# Group Var               0.056    0.070
# =================================================================
#
# -----------------
# rpPU
# 186
# 0.9762118638767011
# 7.809694911013609
# -0.02981842549945819
# 2.1182665705454564
# 1.1151565978857454
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      192         Method:                 REML
# No. Groups:            64          Scale:                  0.0306
# Min. group size:       3           Log-Likelihood:         6.1553
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.296    0.058  5.134 0.000  0.183  0.408
# group[T.baseline]       0.029    0.072  0.405 0.686 -0.112  0.170
# group[T.M1_cTBS]       -0.012    0.081 -0.149 0.881 -0.172  0.147
# time                   -0.090    0.030 -3.016 0.003 -0.149 -0.032
# time:group[T.baseline] -0.001    0.038 -0.030 0.976 -0.075  0.072
# time:group[T.M1_cTBS]   0.047    0.042  1.115 0.265 -0.036  0.130
# Group Var               0.031    0.052
# =================================================================
#
# -----------------
# rpCA
# 186
# 0.005582020108534501
# 0.04465616086827601
# 2.771374409227573
# 0.003169087104723449
# 3.5426447928782894
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      192        Method:                REML
# No. Groups:            64         Scale:                 0.0536
# Min. group size:       3          Log-Likelihood:        -49.5591
# Max. group size:       3          Converged:             Yes
# Mean group size:       3.0
# -----------------------------------------------------------------
#                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept               0.406    0.080  5.104 0.000  0.250  0.562
# group[T.baseline]      -0.067    0.100 -0.675 0.500 -0.262  0.128
# group[T.M1_cTBS]       -0.114    0.113 -1.009 0.313 -0.334  0.107
# time                   -0.270    0.040 -6.806 0.000 -0.348 -0.192
# time:group[T.baseline]  0.138    0.050  2.771 0.006  0.040  0.235
# time:group[T.M1_cTBS]   0.199    0.056  3.543 0.000  0.089  0.309
# Group Var               0.063    0.077
# =================================================================
#
# -----------------

# %%
df['group'] = pd.Categorical(df['group'], categories=['M1_cTBS', 'baseline', 'DLPFC_cTBS'])

# Perform the analysis for each ROI
interaction_results_time_recoded = {}
mixedlm_result = {}

for roi in rois_left + rois_right:
    roi_data = df[df['roi'] == roi].dropna()
    
    # Fit the mixed effects model
    model = smf.mixedlm("beta ~ time * group", roi_data, groups=roi_data['subj'])
#     model = Lmer('beta ~ time * group + (1|subj)',data =roi_data )
#     model = smf.mixedlm("beta ~ time * group_recoded", roi_data, groups=roi_data['subj'], re_formula="~time")
    mixedlm_result[roi] = model.fit()
    
    # Get the p-value of the interaction term
    print(roi)
    print(mixedlm_result[roi].df_resid)
    print(mixedlm_result[roi].pvalues['time:group[T.baseline]'])
    print(mixedlm_result[roi].pvalues['time:group[T.baseline]']*8)
    print(mixedlm_result[roi].tvalues['time:group[T.baseline]'])
    print(mixedlm_result[roi].pvalues['time:group[T.DLPFC_cTBS]']*8)
    print(mixedlm_result[roi].tvalues['time:group[T.DLPFC_cTBS]'])
#     print(result.df_model)
    print(mixedlm_result[roi].summary())
    print('-----------------')
#     interaction_results_time_recoded[roi] = {f"time:group_recoded[T.{group}]": p_val for group, p_val in mixedlm_result.pvalues.items() if "group_recoded" in group}

#     print(mixedlm_result.summary())
# Out:
# laPU
# 186
# 0.2700700368564807
# 2.1605602948518454
# -1.1029012833683585
# 0.09218215813726961
# -2.5264319853504955
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      192         Method:                 REML
# No. Groups:            64          Scale:                  0.0488
# Min. group size:       3           Log-Likelihood:         -44.9340
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.606    0.080  7.589 0.000  0.450  0.763
# group[T.baseline]        -0.005    0.100 -0.048 0.962 -0.201  0.191
# group[T.DLPFC_cTBS]      -0.029    0.113 -0.259 0.796 -0.251  0.192
# time                     -0.081    0.038 -2.130 0.033 -0.155 -0.006
# time:group[T.baseline]   -0.052    0.047 -1.103 0.270 -0.145  0.041
# time:group[T.DLPFC_cTBS] -0.135    0.054 -2.526 0.012 -0.240 -0.030
# Group Var                 0.068    0.084
# ===================================================================
#
# -----------------
# laCA
# 186
# 0.8089460790996702
# 6.471568632797362
# -0.2417858817773114
# 0.0073262466128271465
# -3.31519846154257
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      192         Method:                 REML
# No. Groups:            64          Scale:                  0.0557
# Min. group size:       3           Log-Likelihood:         -50.0509
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.472    0.078  6.040 0.000  0.319  0.625
# group[T.baseline]        -0.046    0.098 -0.472 0.637 -0.238  0.146
# group[T.DLPFC_cTBS]       0.073    0.110  0.657 0.511 -0.144  0.289
# time                     -0.075    0.040 -1.845 0.065 -0.154  0.005
# time:group[T.baseline]   -0.012    0.051 -0.242 0.809 -0.112  0.087
# time:group[T.DLPFC_cTBS] -0.190    0.057 -3.315 0.001 -0.302 -0.078
# Group Var                 0.057    0.071
# ===================================================================
#
# -----------------
# lpPU
# 186
# 0.09018246217195268
# 0.7214596973756214
# -1.6944360072116678
# 0.9090956977743048
# -1.5820552323963022
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                  MixedLM     Dependent Variable:     beta
# No. Observations:       192         Method:                 REML
# No. Groups:             64          Scale:                  0.0364
# Min. group size:        3           Log-Likelihood:         -6.1014
# Max. group size:        3           Converged:              Yes
# Mean group size:        3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.236    0.060  3.945 0.000  0.119  0.354
# group[T.baseline]         0.042    0.075  0.564 0.573 -0.105  0.189
# group[T.DLPFC_cTBS]       0.035    0.085  0.414 0.679 -0.131  0.201
# time                     -0.036    0.033 -1.100 0.271 -0.100  0.028
# time:group[T.baseline]   -0.069    0.041 -1.694 0.090 -0.150  0.011
# time:group[T.DLPFC_cTBS] -0.073    0.046 -1.582 0.114 -0.164  0.017
# Group Var                 0.031    0.050
# ===================================================================
#
# -----------------
# lpCA
# 186
# 0.25012026646242846
# 2.0009621316994277
# -1.1500573128520153
# 0.10149657225442232
# -2.492434536820571
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      192         Method:                 REML
# No. Groups:            64          Scale:                  0.0623
# Min. group size:       3           Log-Likelihood:         -64.2842
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.351    0.087  4.051 0.000  0.181  0.520
# group[T.baseline]         0.017    0.108  0.160 0.873 -0.195  0.230
# group[T.DLPFC_cTBS]       0.054    0.122  0.442 0.659 -0.186  0.294
# time                     -0.098    0.043 -2.287 0.022 -0.182 -0.014
# time:group[T.baseline]   -0.062    0.054 -1.150 0.250 -0.167  0.043
# time:group[T.DLPFC_cTBS] -0.151    0.061 -2.492 0.013 -0.270 -0.032
# Group Var                 0.075    0.085
# ===================================================================
#
# -----------------
# raPU
# 186
# 0.8639180454599533
# 6.911344363679627
# -0.1713888194956123
# 0.15404928127152306
# -2.3405344818783083
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      192         Method:                 REML
# No. Groups:            64          Scale:                  0.0400
# Min. group size:       3           Log-Likelihood:         -24.5262
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.583    0.071  8.259 0.000  0.445  0.721
# group[T.baseline]         0.013    0.088  0.150 0.881 -0.160  0.186
# group[T.DLPFC_cTBS]       0.032    0.100  0.323 0.747 -0.163  0.228
# time                     -0.086    0.034 -2.502 0.012 -0.153 -0.019
# time:group[T.baseline]   -0.007    0.043 -0.171 0.864 -0.092  0.077
# time:group[T.DLPFC_cTBS] -0.114    0.049 -2.341 0.019 -0.209 -0.018
# Group Var                 0.051    0.071
# ===================================================================
#
# -----------------
# raCA
# 186
# 0.6052838032198709
# 4.842270425758967
# -0.516817155359228
# 0.03466433291037555
# -2.8528401167625765
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      192         Method:                 REML
# No. Groups:            64          Scale:                  0.0546
# Min. group size:       3           Log-Likelihood:         -48.0596
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.487    0.077  6.304 0.000  0.335  0.638
# group[T.baseline]        -0.009    0.097 -0.088 0.930 -0.198  0.181
# group[T.DLPFC_cTBS]       0.009    0.109  0.080 0.936 -0.205  0.223
# time                     -0.082    0.040 -2.047 0.041 -0.161 -0.004
# time:group[T.baseline]   -0.026    0.050 -0.517 0.605 -0.124  0.072
# time:group[T.DLPFC_cTBS] -0.162    0.057 -2.853 0.004 -0.273 -0.051
# Group Var                 0.056    0.070
# ===================================================================
#
# -----------------
# rpPU
# 186
# 0.19712176010263216
# 1.5769740808210573
# -1.289795242818159
# 2.1182665705454706
# -1.1151565978857414
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM      Dependent Variable:      beta
# No. Observations:      192          Method:                  REML
# No. Groups:            64           Scale:                   0.0306
# Min. group size:       3            Log-Likelihood:          6.1553
# Max. group size:       3            Converged:               Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.283    0.058  4.923 0.000  0.171  0.396
# group[T.baseline]         0.041    0.072  0.574 0.566 -0.100  0.183
# group[T.DLPFC_cTBS]       0.012    0.081  0.149 0.881 -0.147  0.172
# time                     -0.043    0.030 -1.439 0.150 -0.102  0.016
# time:group[T.baseline]   -0.048    0.038 -1.290 0.197 -0.122  0.025
# time:group[T.DLPFC_cTBS] -0.047    0.042 -1.115 0.265 -0.130  0.036
# Group Var                 0.031    0.052
# ===================================================================
#
# -----------------
# rpCA
# 186
# 0.2181967572226018
# 1.7455740577808143
# -1.231337245336632
# 0.0031690871047233508
# -3.5426447928782974
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM     Dependent Variable:     beta
# No. Observations:      192         Method:                 REML
# No. Groups:            64          Scale:                  0.0536
# Min. group size:       3           Log-Likelihood:         -49.5591
# Max. group size:       3           Converged:              Yes
# Mean group size:       3.0
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.293    0.080  3.676 0.000  0.137  0.449
# group[T.baseline]         0.046    0.100  0.466 0.641 -0.149  0.242
# group[T.DLPFC_cTBS]       0.114    0.113  1.009 0.313 -0.107  0.334
# time                     -0.071    0.040 -1.796 0.073 -0.149  0.007
# time:group[T.baseline]   -0.061    0.050 -1.231 0.218 -0.159  0.036
# time:group[T.DLPFC_cTBS] -0.199    0.056 -3.543 0.000 -0.309 -0.089
# Group Var                 0.063    0.077
# ===================================================================
#
# -----------------

# %%
df_n50 = pd.read_csv('./../data/df_rew1_coef.csv')
# run_to_time = {'r01': 0, 'r02': 1, 'r03': 2}
# df_n50['time'] = df['run'].map(run_to_time)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_n50 = pd.read_csv('./../data/df_rew1_coef.csv')
#
# File ~/anaconda3/envs/LME/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/LME/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/anaconda3/envs/LME/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/LME/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/anaconda3/envs/LME/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './../data/df_rew1_coef.csv'

# %%
df

# %%
df_n50

# %%
df_n50['group'] = df_n50['group'].replace('no_stim', 'baseline')
df_n50

# %%
run_to_time = {'r01': 0, 'r02': 1, 'r03': 2}
df_n50['time'] = df_n50['run'].map(run_to_time)
df_n50

# %%
df_n50['group'] = pd.Categorical(df_n50['group'], categories=['DLPFC_20Hz', 'baseline', 'DLPFC_cTBS'])

# Perform the analysis for each ROI
interaction_results_time_recoded = {}
mixedlm_result = {}

for roi in rois_left + rois_right:
    roi_data = df_n50[df_n50['roi'] == roi].dropna()
    
    # Fit the mixed effects model
    model = smf.mixedlm("beta ~ time * group", roi_data, groups=roi_data['subj'])
#     model = Lmer('beta ~ time * group + (1|subj)',data =roi_data )
#     model = smf.mixedlm("beta ~ time * group_recoded", roi_data, groups=roi_data['subj'], re_formula="~time")
    mixedlm_result[roi] = model.fit()
    
    # Get the p-value of the interaction term
    print(roi)
    print(mixedlm_result[roi].df_resid)
    print(mixedlm_result[roi].pvalues['time:group[T.baseline]'])
    print(mixedlm_result[roi].pvalues['time:group[T.baseline]']*8)
    print(mixedlm_result[roi].tvalues['time:group[T.baseline]'])
    print(mixedlm_result[roi].pvalues['time:group[T.DLPFC_cTBS]'])
    print(mixedlm_result[roi].pvalues['time:group[T.DLPFC_cTBS]']*8)
    print(mixedlm_result[roi].tvalues['time:group[T.DLPFC_cTBS]'])
#     print(result.df_n50_model)
    print(mixedlm_result[roi].summary())
    print('-----------------')
#     interaction_results_time_recoded[roi] = {f"time:group_recoded[T.{group}]": p_val for group, p_val in mixedlm_result.pvalues.items() if "group_recoded" in group}

#     print(mixedlm_result.summary())
